# %%
import inflect
import itertools
import googlemaps
import re
import random
import json
import time
from tqdm import *
from pprint import pprint

# %% [markdown]
# ##### Enter your Google API Key

# %%
# Enter your own Gmaps API
gmaps = googlemaps.Client(key='AIzaSyDd_omELJHX1yjjod5qsWXKIY5cTPk3ANQ')

# %% [markdown]
# ##### The Street and Avenue List; There are some points to note
# After 60th street, names of a few avenues change <br>
# 11th avenue  -> West End Avenue <br>
# 10th Avenue -> Amsterdam Avenue <br>
# 9th Avenue -> Columbus Avenue <br>
# 8th Avenue -> Central Park West

# %%
streets_1 = list(range(1,61))
streets_2 = list(range(61,110))
streets = streets_1 + streets_2
sec_avenues = ['Central Park West', 'Columbus Avenue', 'Amsterdam Avenue', 'West End Avenue' ]
avenues_1 = ['Avenue D', 'Avenue C', 'Avenue B', 'Avenue A'] + list(range(1,4)) + ['Park Avenue'] + list(range(5, 12))
avenues_2 = list(range(1,4)) + ['Park Avenue'] + [5 , 'Central Park West', 'Columbus Avenue', 'Amsterdam Avenue', 'West End Avenue' ]
orient_dict = { 'Avenue D' : 'even',  'Avenue C' : 'odd', 'Avenue B' : 'odd', 'Avenue A' : 'odd', 'Park Avenue': 'even', 'Central Park West':'even', 'Columbus Avenue': 'odd', 'Amsterdam Avenue':'even', 'West End Avenue':'odd'}

# %% [markdown]
# ##### String/Address manipulation functions

# %%
p = inflect.engine()

# converts 10 to 10th
def ordinal(num):
    if isinstance(num, str):
        return num
    else:
        return p.ordinal(num)

# converts st and av num to a string  (2,4) - > 2nd street & 4th Avenue 
def num2str(tup):
    if isinstance(tup[1], str):
        return ordinal(tup[0]) + ' St ' + '& ' + ordinal(tup[1]) 
    else:
        return ordinal(tup[0]) + ' St ' + '& ' + ordinal(tup[1]) + ' Avenue'

# converts 2nd street & 4th Avenue - > (2,4)  
def str2num(address):
    digits = (re.findall(r'\d+',address))
    return (int(digits[0]), int(digits[1]))

# %% [markdown]
# ### The heuristic method of calculating the adjacent intersections
# The street list has been created such as street numbers go from south to north and avenues goes from east to west <br>
# Depending on the traffic direction, Every street and avenue has an orientation [defined in orient() function using orient_dict] <br>
# When intersections() function is called it decides, based on input intersection address's (street, avenue) orientation, it decides the next/previous street/avenue  intersections by calling junc() function <br>
# junc() function gives the next/previous street/avenue by going back to the appropriate street/avenue list

# %%
# tells if the st num and avenue are odd or even 
# odd streets run from right to left; odd avenues go from top to bottom
def intersections(st,av):
    #print (orient(st,'st'), orient(av,'av'))
    if (orient(st,'st') == 'even') & (orient(av,'av') == 'even'):
        result = (st, junc(av, 'av', 'prev')), (junc(st, 'st', 'next'), av)
    elif (orient(st,'st') == 'odd') & (orient(av,'av') == 'odd'):
        result = (st, junc(av, 'av', 'next')), (junc(st, 'st','prev'), av)
    elif (orient(st,'st') == 'even') & (orient(av,'av') == 'odd'):
        result = (st, junc(av, 'av', 'prev')), (junc(st, 'st', 'prev'), av)
    else:
        result = (st, junc(av, 'av', 'next')), ((junc(st,'st', 'next'), av ))
    return num2str(result[0]), num2str(result[1])
    #return num2str(result[0]), num2str(result[1])

# KEY IDEA : odd streets and avenues differ from even ones in their direction of traffic 
def orient(s, typ):
    if isinstance(s, str):
        return orient_dict[s]
    elif (typ == 'av') & (s in [1,2,3]): # avenues 1,2,3 run in the oppsite direction as the other avenues 
        if s%2 == 0:
            return 'odd'
        else:
            return 'even'
    else:
        if s%2 == 0:
            return 'even'
        else:
            return 'odd'
        
def junc(a, typ, direc):
    if typ == 'st':
        index = streets.index(a)
        if direc == 'next':
            if index != len(streets) - 1: # if it is the last street, then returns the same street as one of the adj points
                return streets[index + 1]
            else:
                return a
        if direc == 'prev':
            if index != 0:
                return streets[index - 1]
            else:
                return a      
    else:
        if a in sec_avenues:
            avenues = avenues_2
        else:
            avenues = avenues_1
        index = avenues.index(a)
        if direc == 'next':
            if index != len(avenues) - 1:
                return avenues[index + 1]
            else:
                return a
        if direc == 'prev':
            if index != 0:
                return avenues[index - 1]
            else:
                return a

# %% [markdown]
# ##### Using googlemaps wrapper to find if the address is in Manhattan or not !!
# Locality() gives the locality of an address <br>
# gps_coords() returns the gps coordiates of the address

# %%
# finds the locality of an address
def locality(address):
    if not gmaps.geocode('Intersection of ' + num2str(address)  + 'Manhattan NY'):
        return 'Intersection of ' + num2str(address) +  ' doesnt exist'
    #locality('Intersection of 3rd St & Attorney St Manhattan NYC') returns [] coz intersection of these two streets dont exist
    elif gmaps.geocode('Intersection of ' + num2str(address)  + 'Manhattan NY')[0]['address_components'][1]['long_name'] != 'Manhattan':
        return 'Intersection of ' + num2str(address) +  ' is not in Manhattan'
    else:
        return  gmaps.geocode('Intersection of ' + num2str(address)  + 'Manhattan NY')[0]['address_components'][1]['long_name']

    
# coordinates = geocode_result[0]['geometry']['location']['lat'], geocode_result[0]['geometry']['location']['lng']

def gps_coords(address):
    geocode_result = gmaps.geocode('Intersection of ' + num2str(address)  + 'Manhattan NY')
    if not geocode_result:
        return ('Not found', 'Not found')
    elif geocode_result[0]['address_components'][1]['long_name'] != 'Manhattan':
        return ('Not in Manhattan ', 'Not in Manhattan')
    else:
        lat = geocode_result[0]['geometry']['location']['lat']
        lng = geocode_result[0]['geometry']['location']['lng']
        return lat,lng

# %% [markdown]
# #### Making all combinations of streets and avenues
# ['Avenue D', 'Avenue C', 'Avenue B', 'Avenue A'] end at street 20. So, filtering them out

# %%
junctions = [(st, av) for st in streets_1 for av in avenues_1] + [(st, av) for st in streets_2 for av in avenues_2]# all possible combinations of streets and avenues
junctions = [(a,b) for (a,b) in junctions if not ((a > 20) & (b in ['Avenue D', 'Avenue C', 'Avenue B', 'Avenue A']))]

# %%
len(junctions)
# Out:
# 1181

# %% [markdown]
# ### Testing Outputs

# %% [markdown]
# #### Some sample intersections

# %%
i = 0
while i < 5:
    testing = (junctions[random.randint(0, len(junctions) - 1)])
    print (num2str(testing))
    i += 1
# Out:
# 86th St & West End Avenue
# 75th St & Columbus Avenue
# 20th St & Avenue D
# 3rd St & Avenue B
# 27th St & 8th Avenue

# %% [markdown]
# #### GPS coordinates of some sample intersections

# %%
i = 0
while i < 3:
    testing = (junctions[random.randint(0, len(junctions) - 1)])
    print ("GPS coords of intersection of " + num2str(testing) + " are " + str(gps_coords(testing)[0]) + "," + str(gps_coords(testing)[1]))
    i+=1
# Out:
# GPS coords of intersection of 75th St & Columbus Avenue are 40.7793756,-73.9773846
# GPS coords of intersection of 43rd St & Park Avenue are Not in Manhattan ,Not in Manhattan
# GPS coords of intersection of 12th St & Avenue C are 40.72907180000001,-73.9813401

# %% [markdown]
# #### Testing the intersections() function; it is returning the adjacent intersections

# %%
test = (junctions[random.randint(0, len(junctions) - 1)])
print(num2str(test))
c = intersections(test[0], test[1])
("Adj intersections of " + num2str(test) + " are " + c[0] + " and " + c[1])
# Out:
# 3rd St & Avenue C
# 'Adj intersections of 3rd St & Avenue C are 3rd St & Avenue B and 2nd St & Avenue C'

# %% [markdown]
# ### Creating Adjacency graph

# %%
adj_graph = {}
for address in junctions:
    #print (address)
    adj_graph[num2str(address)] = intersections((address[0]), (address[1]))
adj_graph['10th St & Avenue D']
# Out:
# ('10th St & Avenue D', '11th St & Avenue D')

# %%
adj_graph
# Out:
# {'1st St & Avenue D': ('1st St & Avenue C', '2nd St & Avenue D'),
#  '1st St & Avenue C': ('1st St & Avenue B', '1st St & Avenue C'),
#  '1st St & Avenue B': ('1st St & Avenue A', '1st St & Avenue B'),
#  '1st St & Avenue A': ('1st St & 1st Avenue', '1st St & Avenue A'),
#  '1st St & 1st Avenue': ('1st St & 2nd Avenue', '2nd St & 1st Avenue'),
#  '1st St & 2nd Avenue': ('1st St & 3rd Avenue', '1st St & 2nd Avenue'),
#  '1st St & 3rd Avenue': ('1st St & Park Avenue', '2nd St & 3rd Avenue'),
#  '1st St & Park Avenue': ('1st St & 5th Avenue', '2nd St & Park Avenue'),
#  '1st St & 5th Avenue': ('1st St & 6th Avenue', '1st St & 5th Avenue'),
#  '1st St & 6th Avenue': ('1st St & 7th Avenue', '2nd St & 6th Avenue'),
#  '1st St & 7th Avenue': ('1st St & 8th Avenue', '1st St & 7th Avenue'),
#  '1st St & 8th Avenue': ('1st St & 9th Avenue', '2nd St & 8th Avenue'),
#  '1st St & 9th Avenue': ('1st St & 10th Avenue', '1st St & 9th Avenue'),
#  '1st St & 10th Avenue': ('1st St & 11th Avenue', '2nd St & 10th Avenue'),
#  '1st St & 11th Avenue': ('1st St & 11th Avenue', '1st St & 11th Avenue'),
#  '2nd St & Avenue D': ('2nd St & Avenue D', '3rd St & Avenue D'),
#  '2nd St & Avenue C': ('2nd St & Avenue D', '1st St & Avenue C'),
#  '2nd St & Avenue B': ('2nd St & Avenue C', '1st St & Avenue B'),
#  '2nd St & Avenue A': ('2nd St & Avenue B', '1st St & Avenue A'),
#  '2nd St & 1st Avenue': ('2nd St & Avenue A', '3rd St & 1st Avenue'),
#  '2nd St & 2nd Avenue': ('2nd St & 1st Avenue', '1st St & 2nd Avenue'),
#  '2nd St & 3rd Avenue': ('2nd St & 2nd Avenue', '3rd St & 3rd Avenue'),
#  '2nd St & Park Avenue': ('2nd St & 3rd Avenue', '3rd St & Park Avenue'),
#  '2nd St & 5th Avenue': ('2nd St & Park Avenue', '1st St & 5th Avenue'),
#  '2nd St & 6th Avenue': ('2nd St & 5th Avenue', '3rd St & 6th Avenue'),
#  '2nd St & 7th Avenue': ('2nd St & 6th Avenue', '1st St & 7th Avenue'),
#  '2nd St & 8th Avenue': ('2nd St & 7th Avenue', '3rd St & 8th Avenue'),
#  '2nd St & 9th Avenue': ('2nd St & 8th Avenue', '1st St & 9th Avenue'),
#  '2nd St & 10th Avenue': ('2nd St & 9th Avenue', '3rd St & 10th Avenue'),
#  '2nd St & 11th Avenue': ('2nd St & 10th Avenue', '1st St & 11th Avenue'),
#  '3rd St & Avenue D': ('3rd St & Avenue C', '4th St & Avenue D'),
#  '3rd St & Avenue C': ('3rd St & Avenue B', '2nd St & Avenue C'),
#  '3rd St & Avenue B': ('3rd St & Avenue A', '2nd St & Avenue B'),
#  '3rd St & Avenue A': ('3rd St & 1st Avenue', '2nd St & Avenue A'),
#  '3rd St & 1st Avenue': ('3rd St & 2nd Avenue', '4th St & 1st Avenue'),
#  '3rd St & 2nd Avenue': ('3rd St & 3rd Avenue', '2nd St & 2nd Avenue'),
#  '3rd St & 3rd Avenue': ('3rd St & Park Avenue', '4th St & 3rd Avenue'),
#  '3rd St & Park Avenue': ('3rd St & 5th Avenue', '4th St & Park Avenue'),
#  '3rd St & 5th Avenue': ('3rd St & 6th Avenue', '2nd St & 5th Avenue'),
#  '3rd St & 6th Avenue': ('3rd St & 7th Avenue', '4th St & 6th Avenue'),
#  '3rd St & 7th Avenue': ('3rd St & 8th Avenue', '2nd St & 7th Avenue'),
#  '3rd St & 8th Avenue': ('3rd St & 9th Avenue', '4th St & 8th Avenue'),
#  '3rd St & 9th Avenue': ('3rd St & 10th Avenue', '2nd St & 9th Avenue'),
#  '3rd St & 10th Avenue': ('3rd St & 11th Avenue', '4th St & 10th Avenue'),
#  '3rd St & 11th Avenue': ('3rd St & 11th Avenue', '2nd St & 11th Avenue'),
#  '4th St & Avenue D': ('4th St & Avenue D', '5th St & Avenue D'),
#  '4th St & Avenue C': ('4th St & Avenue D', '3rd St & Avenue C'),
#  '4th St & Avenue B': ('4th St & Avenue C', '3rd St & Avenue B'),
#  '4th St & Avenue A': ('4th St & Avenue B', '3rd St & Avenue A'),
#  '4th St & 1st Avenue': ('4th St & Avenue A', '5th St & 1st Avenue'),
#  '4th St & 2nd Avenue': ('4th St & 1st Avenue', '3rd St & 2nd Avenue'),
#  '4th St & 3rd Avenue': ('4th St & 2nd Avenue', '5th St & 3rd Avenue'),
#  '4th St & Park Avenue': ('4th St & 3rd Avenue', '5th St & Park Avenue'),
#  '4th St & 5th Avenue': ('4th St & Park Avenue', '3rd St & 5th Avenue'),
#  '4th St & 6th Avenue': ('4th St & 5th Avenue', '5th St & 6th Avenue'),
#  '4th St & 7th Avenue': ('4th St & 6th Avenue', '3rd St & 7th Avenue'),
#  '4th St & 8th Avenue': ('4th St & 7th Avenue', '5th St & 8th Avenue'),
#  '4th St & 9th Avenue': ('4th St & 8th Avenue', '3rd St & 9th Avenue'),
#  '4th St & 10th Avenue': ('4th St & 9th Avenue', '5th St & 10th Avenue'),
#  '4th St & 11th Avenue': ('4th St & 10th Avenue', '3rd St & 11th Avenue'),
#  '5th St & Avenue D': ('5th St & Avenue C', '6th St & Avenue D'),
#  '5th St & Avenue C': ('5th St & Avenue B', '4th St & Avenue C'),
#  '5th St & Avenue B': ('5th St & Avenue A', '4th St & Avenue B'),
#  '5th St & Avenue A': ('5th St & 1st Avenue', '4th St & Avenue A'),
#  '5th St & 1st Avenue': ('5th St & 2nd Avenue', '6th St & 1st Avenue'),
#  '5th St & 2nd Avenue': ('5th St & 3rd Avenue', '4th St & 2nd Avenue'),
#  '5th St & 3rd Avenue': ('5th St & Park Avenue', '6th St & 3rd Avenue'),
#  '5th St & Park Avenue': ('5th St & 5th Avenue', '6th St & Park Avenue'),
#  '5th St & 5th Avenue': ('5th St & 6th Avenue', '4th St & 5th Avenue'),
#  '5th St & 6th Avenue': ('5th St & 7th Avenue', '6th St & 6th Avenue'),
#  '5th St & 7th Avenue': ('5th St & 8th Avenue', '4th St & 7th Avenue'),
#  '5th St & 8th Avenue': ('5th St & 9th Avenue', '6th St & 8th Avenue'),
#  '5th St & 9th Avenue': ('5th St & 10th Avenue', '4th St & 9th Avenue'),
#  '5th St & 10th Avenue': ('5th St & 11th Avenue', '6th St & 10th Avenue'),
#  '5th St & 11th Avenue': ('5th St & 11th Avenue', '4th St & 11th Avenue'),
#  '6th St & Avenue D': ('6th St & Avenue D', '7th St & Avenue D'),
#  '6th St & Avenue C': ('6th St & Avenue D', '5th St & Avenue C'),
#  '6th St & Avenue B': ('6th St & Avenue C', '5th St & Avenue B'),
#  '6th St & Avenue A': ('6th St & Avenue B', '5th St & Avenue A'),
#  '6th St & 1st Avenue': ('6th St & Avenue A', '7th St & 1st Avenue'),
#  '6th St & 2nd Avenue': ('6th St & 1st Avenue', '5th St & 2nd Avenue'),
#  '6th St & 3rd Avenue': ('6th St & 2nd Avenue', '7th St & 3rd Avenue'),
#  '6th St & Park Avenue': ('6th St & 3rd Avenue', '7th St & Park Avenue'),
#  '6th St & 5th Avenue': ('6th St & Park Avenue', '5th St & 5th Avenue'),
#  '6th St & 6th Avenue': ('6th St & 5th Avenue', '7th St & 6th Avenue'),
#  '6th St & 7th Avenue': ('6th St & 6th Avenue', '5th St & 7th Avenue'),
#  '6th St & 8th Avenue': ('6th St & 7th Avenue', '7th St & 8th Avenue'),
#  '6th St & 9th Avenue': ('6th St & 8th Avenue', '5th St & 9th Avenue'),
#  '6th St & 10th Avenue': ('6th St & 9th Avenue', '7th St & 10th Avenue'),
#  '6th St & 11th Avenue': ('6th St & 10th Avenue', '5th St & 11th Avenue'),
#  '7th St & Avenue D': ('7th St & Avenue C', '8th St & Avenue D'),
#  '7th St & Avenue C': ('7th St & Avenue B', '6th St & Avenue C'),
#  '7th St & Avenue B': ('7th St & Avenue A', '6th St & Avenue B'),
#  '7th St & Avenue A': ('7th St & 1st Avenue', '6th St & Avenue A'),
#  '7th St & 1st Avenue': ('7th St & 2nd Avenue', '8th St & 1st Avenue'),
#  '7th St & 2nd Avenue': ('7th St & 3rd Avenue', '6th St & 2nd Avenue'),
#  '7th St & 3rd Avenue': ('7th St & Park Avenue', '8th St & 3rd Avenue'),
#  '7th St & Park Avenue': ('7th St & 5th Avenue', '8th St & Park Avenue'),
#  '7th St & 5th Avenue': ('7th St & 6th Avenue', '6th St & 5th Avenue'),
#  '7th St & 6th Avenue': ('7th St & 7th Avenue', '8th St & 6th Avenue'),
#  '7th St & 7th Avenue': ('7th St & 8th Avenue', '6th St & 7th Avenue'),
#  '7th St & 8th Avenue': ('7th St & 9th Avenue', '8th St & 8th Avenue'),
#  '7th St & 9th Avenue': ('7th St & 10th Avenue', '6th St & 9th Avenue'),
#  '7th St & 10th Avenue': ('7th St & 11th Avenue', '8th St & 10th Avenue'),
#  '7th St & 11th Avenue': ('7th St & 11th Avenue', '6th St & 11th Avenue'),
#  '8th St & Avenue D': ('8th St & Avenue D', '9th St & Avenue D'),
#  '8th St & Avenue C': ('8th St & Avenue D', '7th St & Avenue C'),
#  '8th St & Avenue B': ('8th St & Avenue C', '7th St & Avenue B'),
#  '8th St & Avenue A': ('8th St & Avenue B', '7th St & Avenue A'),
#  '8th St & 1st Avenue': ('8th St & Avenue A', '9th St & 1st Avenue'),
#  '8th St & 2nd Avenue': ('8th St & 1st Avenue', '7th St & 2nd Avenue'),
#  '8th St & 3rd Avenue': ('8th St & 2nd Avenue', '9th St & 3rd Avenue'),
#  '8th St & Park Avenue': ('8th St & 3rd Avenue', '9th St & Park Avenue'),
#  '8th St & 5th Avenue': ('8th St & Park Avenue', '7th St & 5th Avenue'),
#  '8th St & 6th Avenue': ('8th St & 5th Avenue', '9th St & 6th Avenue'),
#  '8th St & 7th Avenue': ('8th St & 6th Avenue', '7th St & 7th Avenue'),
#  '8th St & 8th Avenue': ('8th St & 7th Avenue', '9th St & 8th Avenue'),
#  '8th St & 9th Avenue': ('8th St & 8th Avenue', '7th St & 9th Avenue'),
#  '8th St & 10th Avenue': ('8th St & 9th Avenue', '9th St & 10th Avenue'),
#  '8th St & 11th Avenue': ('8th St & 10th Avenue', '7th St & 11th Avenue'),
#  '9th St & Avenue D': ('9th St & Avenue C', '10th St & Avenue D'),
#  '9th St & Avenue C': ('9th St & Avenue B', '8th St & Avenue C'),
#  '9th St & Avenue B': ('9th St & Avenue A', '8th St & Avenue B'),
#  '9th St & Avenue A': ('9th St & 1st Avenue', '8th St & Avenue A'),
#  '9th St & 1st Avenue': ('9th St & 2nd Avenue', '10th St & 1st Avenue'),
#  '9th St & 2nd Avenue': ('9th St & 3rd Avenue', '8th St & 2nd Avenue'),
#  '9th St & 3rd Avenue': ('9th St & Park Avenue', '10th St & 3rd Avenue'),
#  '9th St & Park Avenue': ('9th St & 5th Avenue', '10th St & Park Avenue'),
#  '9th St & 5th Avenue': ('9th St & 6th Avenue', '8th St & 5th Avenue'),
#  '9th St & 6th Avenue': ('9th St & 7th Avenue', '10th St & 6th Avenue'),
#  '9th St & 7th Avenue': ('9th St & 8th Avenue', '8th St & 7th Avenue'),
#  '9th St & 8th Avenue': ('9th St & 9th Avenue', '10th St & 8th Avenue'),
#  '9th St & 9th Avenue': ('9th St & 10th Avenue', '8th St & 9th Avenue'),
#  '9th St & 10th Avenue': ('9th St & 11th Avenue', '10th St & 10th Avenue'),
#  '9th St & 11th Avenue': ('9th St & 11th Avenue', '8th St & 11th Avenue'),
#  '10th St & Avenue D': ('10th St & Avenue D', '11th St & Avenue D'),
#  '10th St & Avenue C': ('10th St & Avenue D', '9th St & Avenue C'),
#  '10th St & Avenue B': ('10th St & Avenue C', '9th St & Avenue B'),
#  '10th St & Avenue A': ('10th St & Avenue B', '9th St & Avenue A'),
#  '10th St & 1st Avenue': ('10th St & Avenue A', '11th St & 1st Avenue'),
#  '10th St & 2nd Avenue': ('10th St & 1st Avenue', '9th St & 2nd Avenue'),
#  '10th St & 3rd Avenue': ('10th St & 2nd Avenue', '11th St & 3rd Avenue'),
#  '10th St & Park Avenue': ('10th St & 3rd Avenue', '11th St & Park Avenue'),
#  '10th St & 5th Avenue': ('10th St & Park Avenue', '9th St & 5th Avenue'),
#  '10th St & 6th Avenue': ('10th St & 5th Avenue', '11th St & 6th Avenue'),
#  '10th St & 7th Avenue': ('10th St & 6th Avenue', '9th St & 7th Avenue'),
#  '10th St & 8th Avenue': ('10th St & 7th Avenue', '11th St & 8th Avenue'),
#  '10th St & 9th Avenue': ('10th St & 8th Avenue', '9th St & 9th Avenue'),
#  '10th St & 10th Avenue': ('10th St & 9th Avenue', '11th St & 10th Avenue'),
#  '10th St & 11th Avenue': ('10th St & 10th Avenue', '9th St & 11th Avenue'),
#  '11th St & Avenue D': ('11th St & Avenue C', '12th St & Avenue D'),
#  '11th St & Avenue C': ('11th St & Avenue B', '10th St & Avenue C'),
#  '11th St & Avenue B': ('11th St & Avenue A', '10th St & Avenue B'),
#  '11th St & Avenue A': ('11th St & 1st Avenue', '10th St & Avenue A'),
#  '11th St & 1st Avenue': ('11th St & 2nd Avenue', '12th St & 1st Avenue'),
#  '11th St & 2nd Avenue': ('11th St & 3rd Avenue', '10th St & 2nd Avenue'),
#  '11th St & 3rd Avenue': ('11th St & Park Avenue', '12th St & 3rd Avenue'),
#  '11th St & Park Avenue': ('11th St & 5th Avenue', '12th St & Park Avenue'),
#  '11th St & 5th Avenue': ('11th St & 6th Avenue', '10th St & 5th Avenue'),
#  '11th St & 6th Avenue': ('11th St & 7th Avenue', '12th St & 6th Avenue'),
#  '11th St & 7th Avenue': ('11th St & 8th Avenue', '10th St & 7th Avenue'),
#  '11th St & 8th Avenue': ('11th St & 9th Avenue', '12th St & 8th Avenue'),
#  '11th St & 9th Avenue': ('11th St & 10th Avenue', '10th St & 9th Avenue'),
#  '11th St & 10th Avenue': ('11th St & 11th Avenue', '12th St & 10th Avenue'),
#  '11th St & 11th Avenue': ('11th St & 11th Avenue', '10th St & 11th Avenue'),
#  '12th St & Avenue D': ('12th St & Avenue D', '13th St & Avenue D'),
#  '12th St & Avenue C': ('12th St & Avenue D', '11th St & Avenue C'),
#  '12th St & Avenue B': ('12th St & Avenue C', '11th St & Avenue B'),
#  '12th St & Avenue A': ('12th St & Avenue B', '11th St & Avenue A'),
#  '12th St & 1st Avenue': ('12th St & Avenue A', '13th St & 1st Avenue'),
#  '12th St & 2nd Avenue': ('12th St & 1st Avenue', '11th St & 2nd Avenue'),
#  '12th St & 3rd Avenue': ('12th St & 2nd Avenue', '13th St & 3rd Avenue'),
#  '12th St & Park Avenue': ('12th St & 3rd Avenue', '13th St & Park Avenue'),
#  '12th St & 5th Avenue': ('12th St & Park Avenue', '11th St & 5th Avenue'),
#  '12th St & 6th Avenue': ('12th St & 5th Avenue', '13th St & 6th Avenue'),
#  '12th St & 7th Avenue': ('12th St & 6th Avenue', '11th St & 7th Avenue'),
#  '12th St & 8th Avenue': ('12th St & 7th Avenue', '13th St & 8th Avenue'),
#  '12th St & 9th Avenue': ('12th St & 8th Avenue', '11th St & 9th Avenue'),
#  '12th St & 10th Avenue': ('12th St & 9th Avenue', '13th St & 10th Avenue'),
#  '12th St & 11th Avenue': ('12th St & 10th Avenue', '11th St & 11th Avenue'),
#  '13th St & Avenue D': ('13th St & Avenue C', '14th St & Avenue D'),
#  '13th St & Avenue C': ('13th St & Avenue B', '12th St & Avenue C'),
#  '13th St & Avenue B': ('13th St & Avenue A', '12th St & Avenue B'),
#  '13th St & Avenue A': ('13th St & 1st Avenue', '12th St & Avenue A'),
#  '13th St & 1st Avenue': ('13th St & 2nd Avenue', '14th St & 1st Avenue'),
#  '13th St & 2nd Avenue': ('13th St & 3rd Avenue', '12th St & 2nd Avenue'),
#  '13th St & 3rd Avenue': ('13th St & Park Avenue', '14th St & 3rd Avenue'),
#  '13th St & Park Avenue': ('13th St & 5th Avenue', '14th St & Park Avenue'),
#  '13th St & 5th Avenue': ('13th St & 6th Avenue', '12th St & 5th Avenue'),
#  '13th St & 6th Avenue': ('13th St & 7th Avenue', '14th St & 6th Avenue'),
#  '13th St & 7th Avenue': ('13th St & 8th Avenue', '12th St & 7th Avenue'),
#  '13th St & 8th Avenue': ('13th St & 9th Avenue', '14th St & 8th Avenue'),
#  '13th St & 9th Avenue': ('13th St & 10th Avenue', '12th St & 9th Avenue'),
#  '13th St & 10th Avenue': ('13th St & 11th Avenue', '14th St & 10th Avenue'),
#  '13th St & 11th Avenue': ('13th St & 11th Avenue', '12th St & 11th Avenue'),
#  '14th St & Avenue D': ('14th St & Avenue D', '15th St & Avenue D'),
#  '14th St & Avenue C': ('14th St & Avenue D', '13th St & Avenue C'),
#  '14th St & Avenue B': ('14th St & Avenue C', '13th St & Avenue B'),
#  '14th St & Avenue A': ('14th St & Avenue B', '13th St & Avenue A'),
#  '14th St & 1st Avenue': ('14th St & Avenue A', '15th St & 1st Avenue'),
#  '14th St & 2nd Avenue': ('14th St & 1st Avenue', '13th St & 2nd Avenue'),
#  '14th St & 3rd Avenue': ('14th St & 2nd Avenue', '15th St & 3rd Avenue'),
#  '14th St & Park Avenue': ('14th St & 3rd Avenue', '15th St & Park Avenue'),
#  '14th St & 5th Avenue': ('14th St & Park Avenue', '13th St & 5th Avenue'),
#  '14th St & 6th Avenue': ('14th St & 5th Avenue', '15th St & 6th Avenue'),
#  '14th St & 7th Avenue': ('14th St & 6th Avenue', '13th St & 7th Avenue'),
#  '14th St & 8th Avenue': ('14th St & 7th Avenue', '15th St & 8th Avenue'),
#  '14th St & 9th Avenue': ('14th St & 8th Avenue', '13th St & 9th Avenue'),
#  '14th St & 10th Avenue': ('14th St & 9th Avenue', '15th St & 10th Avenue'),
#  '14th St & 11th Avenue': ('14th St & 10th Avenue', '13th St & 11th Avenue'),
#  '15th St & Avenue D': ('15th St & Avenue C', '16th St & Avenue D'),
#  '15th St & Avenue C': ('15th St & Avenue B', '14th St & Avenue C'),
#  '15th St & Avenue B': ('15th St & Avenue A', '14th St & Avenue B'),
#  '15th St & Avenue A': ('15th St & 1st Avenue', '14th St & Avenue A'),
#  '15th St & 1st Avenue': ('15th St & 2nd Avenue', '16th St & 1st Avenue'),
#  '15th St & 2nd Avenue': ('15th St & 3rd Avenue', '14th St & 2nd Avenue'),
#  '15th St & 3rd Avenue': ('15th St & Park Avenue', '16th St & 3rd Avenue'),
#  '15th St & Park Avenue': ('15th St & 5th Avenue', '16th St & Park Avenue'),
#  '15th St & 5th Avenue': ('15th St & 6th Avenue', '14th St & 5th Avenue'),
#  '15th St & 6th Avenue': ('15th St & 7th Avenue', '16th St & 6th Avenue'),
#  '15th St & 7th Avenue': ('15th St & 8th Avenue', '14th St & 7th Avenue'),
#  '15th St & 8th Avenue': ('15th St & 9th Avenue', '16th St & 8th Avenue'),
#  '15th St & 9th Avenue': ('15th St & 10th Avenue', '14th St & 9th Avenue'),
#  '15th St & 10th Avenue': ('15th St & 11th Avenue', '16th St & 10th Avenue'),
#  '15th St & 11th Avenue': ('15th St & 11th Avenue', '14th St & 11th Avenue'),
#  '16th St & Avenue D': ('16th St & Avenue D', '17th St & Avenue D'),
#  '16th St & Avenue C': ('16th St & Avenue D', '15th St & Avenue C'),
#  '16th St & Avenue B': ('16th St & Avenue C', '15th St & Avenue B'),
#  '16th St & Avenue A': ('16th St & Avenue B', '15th St & Avenue A'),
#  '16th St & 1st Avenue': ('16th St & Avenue A', '17th St & 1st Avenue'),
#  '16th St & 2nd Avenue': ('16th St & 1st Avenue', '15th St & 2nd Avenue'),
#  '16th St & 3rd Avenue': ('16th St & 2nd Avenue', '17th St & 3rd Avenue'),
#  '16th St & Park Avenue': ('16th St & 3rd Avenue', '17th St & Park Avenue'),
#  '16th St & 5th Avenue': ('16th St & Park Avenue', '15th St & 5th Avenue'),
#  '16th St & 6th Avenue': ('16th St & 5th Avenue', '17th St & 6th Avenue'),
#  '16th St & 7th Avenue': ('16th St & 6th Avenue', '15th St & 7th Avenue'),
#  '16th St & 8th Avenue': ('16th St & 7th Avenue', '17th St & 8th Avenue'),
#  '16th St & 9th Avenue': ('16th St & 8th Avenue', '15th St & 9th Avenue'),
#  '16th St & 10th Avenue': ('16th St & 9th Avenue', '17th St & 10th Avenue'),
#  '16th St & 11th Avenue': ('16th St & 10th Avenue', '15th St & 11th Avenue'),
#  '17th St & Avenue D': ('17th St & Avenue C', '18th St & Avenue D'),
#  '17th St & Avenue C': ('17th St & Avenue B', '16th St & Avenue C'),
#  '17th St & Avenue B': ('17th St & Avenue A', '16th St & Avenue B'),
#  '17th St & Avenue A': ('17th St & 1st Avenue', '16th St & Avenue A'),
#  '17th St & 1st Avenue': ('17th St & 2nd Avenue', '18th St & 1st Avenue'),
#  '17th St & 2nd Avenue': ('17th St & 3rd Avenue', '16th St & 2nd Avenue'),
#  '17th St & 3rd Avenue': ('17th St & Park Avenue', '18th St & 3rd Avenue'),
#  '17th St & Park Avenue': ('17th St & 5th Avenue', '18th St & Park Avenue'),
#  '17th St & 5th Avenue': ('17th St & 6th Avenue', '16th St & 5th Avenue'),
#  '17th St & 6th Avenue': ('17th St & 7th Avenue', '18th St & 6th Avenue'),
#  '17th St & 7th Avenue': ('17th St & 8th Avenue', '16th St & 7th Avenue'),
#  '17th St & 8th Avenue': ('17th St & 9th Avenue', '18th St & 8th Avenue'),
#  '17th St & 9th Avenue': ('17th St & 10th Avenue', '16th St & 9th Avenue'),
#  '17th St & 10th Avenue': ('17th St & 11th Avenue', '18th St & 10th Avenue'),
#  '17th St & 11th Avenue': ('17th St & 11th Avenue', '16th St & 11th Avenue'),
#  '18th St & Avenue D': ('18th St & Avenue D', '19th St & Avenue D'),
#  '18th St & Avenue C': ('18th St & Avenue D', '17th St & Avenue C'),
#  '18th St & Avenue B': ('18th St & Avenue C', '17th St & Avenue B'),
#  '18th St & Avenue A': ('18th St & Avenue B', '17th St & Avenue A'),
#  '18th St & 1st Avenue': ('18th St & Avenue A', '19th St & 1st Avenue'),
#  '18th St & 2nd Avenue': ('18th St & 1st Avenue', '17th St & 2nd Avenue'),
#  '18th St & 3rd Avenue': ('18th St & 2nd Avenue', '19th St & 3rd Avenue'),
#  '18th St & Park Avenue': ('18th St & 3rd Avenue', '19th St & Park Avenue'),
#  '18th St & 5th Avenue': ('18th St & Park Avenue', '17th St & 5th Avenue'),
#  '18th St & 6th Avenue': ('18th St & 5th Avenue', '19th St & 6th Avenue'),
#  '18th St & 7th Avenue': ('18th St & 6th Avenue', '17th St & 7th Avenue'),
#  '18th St & 8th Avenue': ('18th St & 7th Avenue', '19th St & 8th Avenue'),
#  '18th St & 9th Avenue': ('18th St & 8th Avenue', '17th St & 9th Avenue'),
#  '18th St & 10th Avenue': ('18th St & 9th Avenue', '19th St & 10th Avenue'),
#  '18th St & 11th Avenue': ('18th St & 10th Avenue', '17th St & 11th Avenue'),
#  '19th St & Avenue D': ('19th St & Avenue C', '20th St & Avenue D'),
#  '19th St & Avenue C': ('19th St & Avenue B', '18th St & Avenue C'),
#  '19th St & Avenue B': ('19th St & Avenue A', '18th St & Avenue B'),
#  '19th St & Avenue A': ('19th St & 1st Avenue', '18th St & Avenue A'),
#  '19th St & 1st Avenue': ('19th St & 2nd Avenue', '20th St & 1st Avenue'),
#  '19th St & 2nd Avenue': ('19th St & 3rd Avenue', '18th St & 2nd Avenue'),
#  '19th St & 3rd Avenue': ('19th St & Park Avenue', '20th St & 3rd Avenue'),
#  '19th St & Park Avenue': ('19th St & 5th Avenue', '20th St & Park Avenue'),
#  '19th St & 5th Avenue': ('19th St & 6th Avenue', '18th St & 5th Avenue'),
#  '19th St & 6th Avenue': ('19th St & 7th Avenue', '20th St & 6th Avenue'),
#  '19th St & 7th Avenue': ('19th St & 8th Avenue', '18th St & 7th Avenue'),
#  '19th St & 8th Avenue': ('19th St & 9th Avenue', '20th St & 8th Avenue'),
#  '19th St & 9th Avenue': ('19th St & 10th Avenue', '18th St & 9th Avenue'),
#  '19th St & 10th Avenue': ('19th St & 11th Avenue', '20th St & 10th Avenue'),
#  '19th St & 11th Avenue': ('19th St & 11th Avenue', '18th St & 11th Avenue'),
#  '20th St & Avenue D': ('20th St & Avenue D', '21st St & Avenue D'),
#  '20th St & Avenue C': ('20th St & Avenue D', '19th St & Avenue C'),
#  '20th St & Avenue B': ('20th St & Avenue C', '19th St & Avenue B'),
#  '20th St & Avenue A': ('20th St & Avenue B', '19th St & Avenue A'),
#  '20th St & 1st Avenue': ('20th St & Avenue A', '21st St & 1st Avenue'),
#  '20th St & 2nd Avenue': ('20th St & 1st Avenue', '19th St & 2nd Avenue'),
#  '20th St & 3rd Avenue': ('20th St & 2nd Avenue', '21st St & 3rd Avenue'),
#  '20th St & Park Avenue': ('20th St & 3rd Avenue', '21st St & Park Avenue'),
#  '20th St & 5th Avenue': ('20th St & Park Avenue', '19th St & 5th Avenue'),
#  '20th St & 6th Avenue': ('20th St & 5th Avenue', '21st St & 6th Avenue'),
#  '20th St & 7th Avenue': ('20th St & 6th Avenue', '19th St & 7th Avenue'),
#  '20th St & 8th Avenue': ('20th St & 7th Avenue', '21st St & 8th Avenue'),
#  '20th St & 9th Avenue': ('20th St & 8th Avenue', '19th St & 9th Avenue'),
#  '20th St & 10th Avenue': ('20th St & 9th Avenue', '21st St & 10th Avenue'),
#  '20th St & 11th Avenue': ('20th St & 10th Avenue', '19th St & 11th Avenue'),
#  '21st St & 1st Avenue': ('21st St & 2nd Avenue', '22nd St & 1st Avenue'),
#  '21st St & 2nd Avenue': ('21st St & 3rd Avenue', '20th St & 2nd Avenue'),
#  '21st St & 3rd Avenue': ('21st St & Park Avenue', '22nd St & 3rd Avenue'),
#  '21st St & Park Avenue': ('21st St & 5th Avenue', '22nd St & Park Avenue'),
#  '21st St & 5th Avenue': ('21st St & 6th Avenue', '20th St & 5th Avenue'),
#  '21st St & 6th Avenue': ('21st St & 7th Avenue', '22nd St & 6th Avenue'),
#  '21st St & 7th Avenue': ('21st St & 8th Avenue', '20th St & 7th Avenue'),
#  '21st St & 8th Avenue': ('21st St & 9th Avenue', '22nd St & 8th Avenue'),
#  '21st St & 9th Avenue': ('21st St & 10th Avenue', '20th St & 9th Avenue'),
#  '21st St & 10th Avenue': ('21st St & 11th Avenue', '22nd St & 10th Avenue'),
#  '21st St & 11th Avenue': ('21st St & 11th Avenue', '20th St & 11th Avenue'),
#  '22nd St & 1st Avenue': ('22nd St & Avenue A', '23rd St & 1st Avenue'),
#  '22nd St & 2nd Avenue': ('22nd St & 1st Avenue', '21st St & 2nd Avenue'),
#  '22nd St & 3rd Avenue': ('22nd St & 2nd Avenue', '23rd St & 3rd Avenue'),
#  '22nd St & Park Avenue': ('22nd St & 3rd Avenue', '23rd St & Park Avenue'),
#  '22nd St & 5th Avenue': ('22nd St & Park Avenue', '21st St & 5th Avenue'),
#  '22nd St & 6th Avenue': ('22nd St & 5th Avenue', '23rd St & 6th Avenue'),
#  '22nd St & 7th Avenue': ('22nd St & 6th Avenue', '21st St & 7th Avenue'),
#  '22nd St & 8th Avenue': ('22nd St & 7th Avenue', '23rd St & 8th Avenue'),
#  '22nd St & 9th Avenue': ('22nd St & 8th Avenue', '21st St & 9th Avenue'),
#  '22nd St & 10th Avenue': ('22nd St & 9th Avenue', '23rd St & 10th Avenue'),
#  '22nd St & 11th Avenue': ('22nd St & 10th Avenue', '21st St & 11th Avenue'),
#  '23rd St & 1st Avenue': ('23rd St & 2nd Avenue', '24th St & 1st Avenue'),
#  '23rd St & 2nd Avenue': ('23rd St & 3rd Avenue', '22nd St & 2nd Avenue'),
#  '23rd St & 3rd Avenue': ('23rd St & Park Avenue', '24th St & 3rd Avenue'),
#  '23rd St & Park Avenue': ('23rd St & 5th Avenue', '24th St & Park Avenue'),
#  '23rd St & 5th Avenue': ('23rd St & 6th Avenue', '22nd St & 5th Avenue'),
#  '23rd St & 6th Avenue': ('23rd St & 7th Avenue', '24th St & 6th Avenue'),
#  '23rd St & 7th Avenue': ('23rd St & 8th Avenue', '22nd St & 7th Avenue'),
#  '23rd St & 8th Avenue': ('23rd St & 9th Avenue', '24th St & 8th Avenue'),
#  '23rd St & 9th Avenue': ('23rd St & 10th Avenue', '22nd St & 9th Avenue'),
#  '23rd St & 10th Avenue': ('23rd St & 11th Avenue', '24th St & 10th Avenue'),
#  '23rd St & 11th Avenue': ('23rd St & 11th Avenue', '22nd St & 11th Avenue'),
#  '24th St & 1st Avenue': ('24th St & Avenue A', '25th St & 1st Avenue'),
#  '24th St & 2nd Avenue': ('24th St & 1st Avenue', '23rd St & 2nd Avenue'),
#  '24th St & 3rd Avenue': ('24th St & 2nd Avenue', '25th St & 3rd Avenue'),
#  '24th St & Park Avenue': ('24th St & 3rd Avenue', '25th St & Park Avenue'),
#  '24th St & 5th Avenue': ('24th St & Park Avenue', '23rd St & 5th Avenue'),
#  '24th St & 6th Avenue': ('24th St & 5th Avenue', '25th St & 6th Avenue'),
#  '24th St & 7th Avenue': ('24th St & 6th Avenue', '23rd St & 7th Avenue'),
#  '24th St & 8th Avenue': ('24th St & 7th Avenue', '25th St & 8th Avenue'),
#  '24th St & 9th Avenue': ('24th St & 8th Avenue', '23rd St & 9th Avenue'),
#  '24th St & 10th Avenue': ('24th St & 9th Avenue', '25th St & 10th Avenue'),
#  '24th St & 11th Avenue': ('24th St & 10th Avenue', '23rd St & 11th Avenue'),
#  '25th St & 1st Avenue': ('25th St & 2nd Avenue', '26th St & 1st Avenue'),
#  '25th St & 2nd Avenue': ('25th St & 3rd Avenue', '24th St & 2nd Avenue'),
#  '25th St & 3rd Avenue': ('25th St & Park Avenue', '26th St & 3rd Avenue'),
#  '25th St & Park Avenue': ('25th St & 5th Avenue', '26th St & Park Avenue'),
#  '25th St & 5th Avenue': ('25th St & 6th Avenue', '24th St & 5th Avenue'),
#  '25th St & 6th Avenue': ('25th St & 7th Avenue', '26th St & 6th Avenue'),
#  '25th St & 7th Avenue': ('25th St & 8th Avenue', '24th St & 7th Avenue'),
#  '25th St & 8th Avenue': ('25th St & 9th Avenue', '26th St & 8th Avenue'),
#  '25th St & 9th Avenue': ('25th St & 10th Avenue', '24th St & 9th Avenue'),
#  '25th St & 10th Avenue': ('25th St & 11th Avenue', '26th St & 10th Avenue'),
#  '25th St & 11th Avenue': ('25th St & 11th Avenue', '24th St & 11th Avenue'),
#  '26th St & 1st Avenue': ('26th St & Avenue A', '27th St & 1st Avenue'),
#  '26th St & 2nd Avenue': ('26th St & 1st Avenue', '25th St & 2nd Avenue'),
#  '26th St & 3rd Avenue': ('26th St & 2nd Avenue', '27th St & 3rd Avenue'),
#  '26th St & Park Avenue': ('26th St & 3rd Avenue', '27th St & Park Avenue'),
#  '26th St & 5th Avenue': ('26th St & Park Avenue', '25th St & 5th Avenue'),
#  '26th St & 6th Avenue': ('26th St & 5th Avenue', '27th St & 6th Avenue'),
#  '26th St & 7th Avenue': ('26th St & 6th Avenue', '25th St & 7th Avenue'),
#  '26th St & 8th Avenue': ('26th St & 7th Avenue', '27th St & 8th Avenue'),
#  '26th St & 9th Avenue': ('26th St & 8th Avenue', '25th St & 9th Avenue'),
#  '26th St & 10th Avenue': ('26th St & 9th Avenue', '27th St & 10th Avenue'),
#  '26th St & 11th Avenue': ('26th St & 10th Avenue', '25th St & 11th Avenue'),
#  '27th St & 1st Avenue': ('27th St & 2nd Avenue', '28th St & 1st Avenue'),
#  '27th St & 2nd Avenue': ('27th St & 3rd Avenue', '26th St & 2nd Avenue'),
#  '27th St & 3rd Avenue': ('27th St & Park Avenue', '28th St & 3rd Avenue'),
#  '27th St & Park Avenue': ('27th St & 5th Avenue', '28th St & Park Avenue'),
#  '27th St & 5th Avenue': ('27th St & 6th Avenue', '26th St & 5th Avenue'),
#  '27th St & 6th Avenue': ('27th St & 7th Avenue', '28th St & 6th Avenue'),
#  '27th St & 7th Avenue': ('27th St & 8th Avenue', '26th St & 7th Avenue'),
#  '27th St & 8th Avenue': ('27th St & 9th Avenue', '28th St & 8th Avenue'),
#  '27th St & 9th Avenue': ('27th St & 10th Avenue', '26th St & 9th Avenue'),
#  '27th St & 10th Avenue': ('27th St & 11th Avenue', '28th St & 10th Avenue'),
#  '27th St & 11th Avenue': ('27th St & 11th Avenue', '26th St & 11th Avenue'),
#  '28th St & 1st Avenue': ('28th St & Avenue A', '29th St & 1st Avenue'),
#  '28th St & 2nd Avenue': ('28th St & 1st Avenue', '27th St & 2nd Avenue'),
#  '28th St & 3rd Avenue': ('28th St & 2nd Avenue', '29th St & 3rd Avenue'),
#  '28th St & Park Avenue': ('28th St & 3rd Avenue', '29th St & Park Avenue'),
#  '28th St & 5th Avenue': ('28th St & Park Avenue', '27th St & 5th Avenue'),
#  '28th St & 6th Avenue': ('28th St & 5th Avenue', '29th St & 6th Avenue'),
#  '28th St & 7th Avenue': ('28th St & 6th Avenue', '27th St & 7th Avenue'),
#  '28th St & 8th Avenue': ('28th St & 7th Avenue', '29th St & 8th Avenue'),
#  '28th St & 9th Avenue': ('28th St & 8th Avenue', '27th St & 9th Avenue'),
#  '28th St & 10th Avenue': ('28th St & 9th Avenue', '29th St & 10th Avenue'),
#  '28th St & 11th Avenue': ('28th St & 10th Avenue', '27th St & 11th Avenue'),
#  '29th St & 1st Avenue': ('29th St & 2nd Avenue', '30th St & 1st Avenue'),
#  '29th St & 2nd Avenue': ('29th St & 3rd Avenue', '28th St & 2nd Avenue'),
#  '29th St & 3rd Avenue': ('29th St & Park Avenue', '30th St & 3rd Avenue'),
#  '29th St & Park Avenue': ('29th St & 5th Avenue', '30th St & Park Avenue'),
#  '29th St & 5th Avenue': ('29th St & 6th Avenue', '28th St & 5th Avenue'),
#  '29th St & 6th Avenue': ('29th St & 7th Avenue', '30th St & 6th Avenue'),
#  '29th St & 7th Avenue': ('29th St & 8th Avenue', '28th St & 7th Avenue'),
#  '29th St & 8th Avenue': ('29th St & 9th Avenue', '30th St & 8th Avenue'),
#  '29th St & 9th Avenue': ('29th St & 10th Avenue', '28th St & 9th Avenue'),
#  '29th St & 10th Avenue': ('29th St & 11th Avenue', '30th St & 10th Avenue'),
#  '29th St & 11th Avenue': ('29th St & 11th Avenue', '28th St & 11th Avenue'),
#  '30th St & 1st Avenue': ('30th St & Avenue A', '31st St & 1st Avenue'),
#  '30th St & 2nd Avenue': ('30th St & 1st Avenue', '29th St & 2nd Avenue'),
#  '30th St & 3rd Avenue': ('30th St & 2nd Avenue', '31st St & 3rd Avenue'),
#  '30th St & Park Avenue': ('30th St & 3rd Avenue', '31st St & Park Avenue'),
#  '30th St & 5th Avenue': ('30th St & Park Avenue', '29th St & 5th Avenue'),
#  '30th St & 6th Avenue': ('30th St & 5th Avenue', '31st St & 6th Avenue'),
#  '30th St & 7th Avenue': ('30th St & 6th Avenue', '29th St & 7th Avenue'),
#  '30th St & 8th Avenue': ('30th St & 7th Avenue', '31st St & 8th Avenue'),
#  '30th St & 9th Avenue': ('30th St & 8th Avenue', '29th St & 9th Avenue'),
#  '30th St & 10th Avenue': ('30th St & 9th Avenue', '31st St & 10th Avenue'),
#  '30th St & 11th Avenue': ('30th St & 10th Avenue', '29th St & 11th Avenue'),
#  '31st St & 1st Avenue': ('31st St & 2nd Avenue', '32nd St & 1st Avenue'),
#  '31st St & 2nd Avenue': ('31st St & 3rd Avenue', '30th St & 2nd Avenue'),
#  '31st St & 3rd Avenue': ('31st St & Park Avenue', '32nd St & 3rd Avenue'),
#  '31st St & Park Avenue': ('31st St & 5th Avenue', '32nd St & Park Avenue'),
#  '31st St & 5th Avenue': ('31st St & 6th Avenue', '30th St & 5th Avenue'),
#  '31st St & 6th Avenue': ('31st St & 7th Avenue', '32nd St & 6th Avenue'),
#  '31st St & 7th Avenue': ('31st St & 8th Avenue', '30th St & 7th Avenue'),
#  '31st St & 8th Avenue': ('31st St & 9th Avenue', '32nd St & 8th Avenue'),
#  '31st St & 9th Avenue': ('31st St & 10th Avenue', '30th St & 9th Avenue'),
#  '31st St & 10th Avenue': ('31st St & 11th Avenue', '32nd St & 10th Avenue'),
#  '31st St & 11th Avenue': ('31st St & 11th Avenue', '30th St & 11th Avenue'),
#  '32nd St & 1st Avenue': ('32nd St & Avenue A', '33rd St & 1st Avenue'),
#  '32nd St & 2nd Avenue': ('32nd St & 1st Avenue', '31st St & 2nd Avenue'),
#  '32nd St & 3rd Avenue': ('32nd St & 2nd Avenue', '33rd St & 3rd Avenue'),
#  '32nd St & Park Avenue': ('32nd St & 3rd Avenue', '33rd St & Park Avenue'),
#  '32nd St & 5th Avenue': ('32nd St & Park Avenue', '31st St & 5th Avenue'),
#  '32nd St & 6th Avenue': ('32nd St & 5th Avenue', '33rd St & 6th Avenue'),
#  '32nd St & 7th Avenue': ('32nd St & 6th Avenue', '31st St & 7th Avenue'),
#  '32nd St & 8th Avenue': ('32nd St & 7th Avenue', '33rd St & 8th Avenue'),
#  '32nd St & 9th Avenue': ('32nd St & 8th Avenue', '31st St & 9th Avenue'),
#  '32nd St & 10th Avenue': ('32nd St & 9th Avenue', '33rd St & 10th Avenue'),
#  '32nd St & 11th Avenue': ('32nd St & 10th Avenue', '31st St & 11th Avenue'),
#  '33rd St & 1st Avenue': ('33rd St & 2nd Avenue', '34th St & 1st Avenue'),
#  '33rd St & 2nd Avenue': ('33rd St & 3rd Avenue', '32nd St & 2nd Avenue'),
#  '33rd St & 3rd Avenue': ('33rd St & Park Avenue', '34th St & 3rd Avenue'),
#  '33rd St & Park Avenue': ('33rd St & 5th Avenue', '34th St & Park Avenue'),
#  '33rd St & 5th Avenue': ('33rd St & 6th Avenue', '32nd St & 5th Avenue'),
#  '33rd St & 6th Avenue': ('33rd St & 7th Avenue', '34th St & 6th Avenue'),
#  '33rd St & 7th Avenue': ('33rd St & 8th Avenue', '32nd St & 7th Avenue'),
#  '33rd St & 8th Avenue': ('33rd St & 9th Avenue', '34th St & 8th Avenue'),
#  '33rd St & 9th Avenue': ('33rd St & 10th Avenue', '32nd St & 9th Avenue'),
#  '33rd St & 10th Avenue': ('33rd St & 11th Avenue', '34th St & 10th Avenue'),
#  '33rd St & 11th Avenue': ('33rd St & 11th Avenue', '32nd St & 11th Avenue'),
#  '34th St & 1st Avenue': ('34th St & Avenue A', '35th St & 1st Avenue'),
#  '34th St & 2nd Avenue': ('34th St & 1st Avenue', '33rd St & 2nd Avenue'),
#  '34th St & 3rd Avenue': ('34th St & 2nd Avenue', '35th St & 3rd Avenue'),
#  '34th St & Park Avenue': ('34th St & 3rd Avenue', '35th St & Park Avenue'),
#  '34th St & 5th Avenue': ('34th St & Park Avenue', '33rd St & 5th Avenue'),
#  '34th St & 6th Avenue': ('34th St & 5th Avenue', '35th St & 6th Avenue'),
#  '34th St & 7th Avenue': ('34th St & 6th Avenue', '33rd St & 7th Avenue'),
#  '34th St & 8th Avenue': ('34th St & 7th Avenue', '35th St & 8th Avenue'),
#  '34th St & 9th Avenue': ('34th St & 8th Avenue', '33rd St & 9th Avenue'),
#  '34th St & 10th Avenue': ('34th St & 9th Avenue', '35th St & 10th Avenue'),
#  '34th St & 11th Avenue': ('34th St & 10th Avenue', '33rd St & 11th Avenue'),
#  '35th St & 1st Avenue': ('35th St & 2nd Avenue', '36th St & 1st Avenue'),
#  '35th St & 2nd Avenue': ('35th St & 3rd Avenue', '34th St & 2nd Avenue'),
#  '35th St & 3rd Avenue': ('35th St & Park Avenue', '36th St & 3rd Avenue'),
#  '35th St & Park Avenue': ('35th St & 5th Avenue', '36th St & Park Avenue'),
#  '35th St & 5th Avenue': ('35th St & 6th Avenue', '34th St & 5th Avenue'),
#  '35th St & 6th Avenue': ('35th St & 7th Avenue', '36th St & 6th Avenue'),
#  '35th St & 7th Avenue': ('35th St & 8th Avenue', '34th St & 7th Avenue'),
#  '35th St & 8th Avenue': ('35th St & 9th Avenue', '36th St & 8th Avenue'),
#  '35th St & 9th Avenue': ('35th St & 10th Avenue', '34th St & 9th Avenue'),
#  '35th St & 10th Avenue': ('35th St & 11th Avenue', '36th St & 10th Avenue'),
#  '35th St & 11th Avenue': ('35th St & 11th Avenue', '34th St & 11th Avenue'),
#  '36th St & 1st Avenue': ('36th St & Avenue A', '37th St & 1st Avenue'),
#  '36th St & 2nd Avenue': ('36th St & 1st Avenue', '35th St & 2nd Avenue'),
#  '36th St & 3rd Avenue': ('36th St & 2nd Avenue', '37th St & 3rd Avenue'),
#  '36th St & Park Avenue': ('36th St & 3rd Avenue', '37th St & Park Avenue'),
#  '36th St & 5th Avenue': ('36th St & Park Avenue', '35th St & 5th Avenue'),
#  '36th St & 6th Avenue': ('36th St & 5th Avenue', '37th St & 6th Avenue'),
#  '36th St & 7th Avenue': ('36th St & 6th Avenue', '35th St & 7th Avenue'),
#  '36th St & 8th Avenue': ('36th St & 7th Avenue', '37th St & 8th Avenue'),
#  '36th St & 9th Avenue': ('36th St & 8th Avenue', '35th St & 9th Avenue'),
#  '36th St & 10th Avenue': ('36th St & 9th Avenue', '37th St & 10th Avenue'),
#  '36th St & 11th Avenue': ('36th St & 10th Avenue', '35th St & 11th Avenue'),
#  '37th St & 1st Avenue': ('37th St & 2nd Avenue', '38th St & 1st Avenue'),
#  '37th St & 2nd Avenue': ('37th St & 3rd Avenue', '36th St & 2nd Avenue'),
#  '37th St & 3rd Avenue': ('37th St & Park Avenue', '38th St & 3rd Avenue'),
#  '37th St & Park Avenue': ('37th St & 5th Avenue', '38th St & Park Avenue'),
#  '37th St & 5th Avenue': ('37th St & 6th Avenue', '36th St & 5th Avenue'),
#  '37th St & 6th Avenue': ('37th St & 7th Avenue', '38th St & 6th Avenue'),
#  '37th St & 7th Avenue': ('37th St & 8th Avenue', '36th St & 7th Avenue'),
#  '37th St & 8th Avenue': ('37th St & 9th Avenue', '38th St & 8th Avenue'),
#  '37th St & 9th Avenue': ('37th St & 10th Avenue', '36th St & 9th Avenue'),
#  '37th St & 10th Avenue': ('37th St & 11th Avenue', '38th St & 10th Avenue'),
#  '37th St & 11th Avenue': ('37th St & 11th Avenue', '36th St & 11th Avenue'),
#  '38th St & 1st Avenue': ('38th St & Avenue A', '39th St & 1st Avenue'),
#  '38th St & 2nd Avenue': ('38th St & 1st Avenue', '37th St & 2nd Avenue'),
#  '38th St & 3rd Avenue': ('38th St & 2nd Avenue', '39th St & 3rd Avenue'),
#  '38th St & Park Avenue': ('38th St & 3rd Avenue', '39th St & Park Avenue'),
#  '38th St & 5th Avenue': ('38th St & Park Avenue', '37th St & 5th Avenue'),
#  '38th St & 6th Avenue': ('38th St & 5th Avenue', '39th St & 6th Avenue'),
#  '38th St & 7th Avenue': ('38th St & 6th Avenue', '37th St & 7th Avenue'),
#  '38th St & 8th Avenue': ('38th St & 7th Avenue', '39th St & 8th Avenue'),
#  '38th St & 9th Avenue': ('38th St & 8th Avenue', '37th St & 9th Avenue'),
#  '38th St & 10th Avenue': ('38th St & 9th Avenue', '39th St & 10th Avenue'),
#  '38th St & 11th Avenue': ('38th St & 10th Avenue', '37th St & 11th Avenue'),
#  '39th St & 1st Avenue': ('39th St & 2nd Avenue', '40th St & 1st Avenue'),
#  '39th St & 2nd Avenue': ('39th St & 3rd Avenue', '38th St & 2nd Avenue'),
#  '39th St & 3rd Avenue': ('39th St & Park Avenue', '40th St & 3rd Avenue'),
#  '39th St & Park Avenue': ('39th St & 5th Avenue', '40th St & Park Avenue'),
#  '39th St & 5th Avenue': ('39th St & 6th Avenue', '38th St & 5th Avenue'),
#  '39th St & 6th Avenue': ('39th St & 7th Avenue', '40th St & 6th Avenue'),
#  '39th St & 7th Avenue': ('39th St & 8th Avenue', '38th St & 7th Avenue'),
#  '39th St & 8th Avenue': ('39th St & 9th Avenue', '40th St & 8th Avenue'),
#  '39th St & 9th Avenue': ('39th St & 10th Avenue', '38th St & 9th Avenue'),
#  '39th St & 10th Avenue': ('39th St & 11th Avenue', '40th St & 10th Avenue'),
#  '39th St & 11th Avenue': ('39th St & 11th Avenue', '38th St & 11th Avenue'),
#  '40th St & 1st Avenue': ('40th St & Avenue A', '41st St & 1st Avenue'),
#  '40th St & 2nd Avenue': ('40th St & 1st Avenue', '39th St & 2nd Avenue'),
#  '40th St & 3rd Avenue': ('40th St & 2nd Avenue', '41st St & 3rd Avenue'),
#  '40th St & Park Avenue': ('40th St & 3rd Avenue', '41st St & Park Avenue'),
#  '40th St & 5th Avenue': ('40th St & Park Avenue', '39th St & 5th Avenue'),
#  '40th St & 6th Avenue': ('40th St & 5th Avenue', '41st St & 6th Avenue'),
#  '40th St & 7th Avenue': ('40th St & 6th Avenue', '39th St & 7th Avenue'),
#  '40th St & 8th Avenue': ('40th St & 7th Avenue', '41st St & 8th Avenue'),
#  '40th St & 9th Avenue': ('40th St & 8th Avenue', '39th St & 9th Avenue'),
#  '40th St & 10th Avenue': ('40th St & 9th Avenue', '41st St & 10th Avenue'),
#  '40th St & 11th Avenue': ('40th St & 10th Avenue', '39th St & 11th Avenue'),
#  '41st St & 1st Avenue': ('41st St & 2nd Avenue', '42nd St & 1st Avenue'),
#  '41st St & 2nd Avenue': ('41st St & 3rd Avenue', '40th St & 2nd Avenue'),
#  '41st St & 3rd Avenue': ('41st St & Park Avenue', '42nd St & 3rd Avenue'),
#  '41st St & Park Avenue': ('41st St & 5th Avenue', '42nd St & Park Avenue'),
#  '41st St & 5th Avenue': ('41st St & 6th Avenue', '40th St & 5th Avenue'),
#  '41st St & 6th Avenue': ('41st St & 7th Avenue', '42nd St & 6th Avenue'),
#  '41st St & 7th Avenue': ('41st St & 8th Avenue', '40th St & 7th Avenue'),
#  '41st St & 8th Avenue': ('41st St & 9th Avenue', '42nd St & 8th Avenue'),
#  '41st St & 9th Avenue': ('41st St & 10th Avenue', '40th St & 9th Avenue'),
#  '41st St & 10th Avenue': ('41st St & 11th Avenue', '42nd St & 10th Avenue'),
#  '41st St & 11th Avenue': ('41st St & 11th Avenue', '40th St & 11th Avenue'),
#  '42nd St & 1st Avenue': ('42nd St & Avenue A', '43rd St & 1st Avenue'),
#  '42nd St & 2nd Avenue': ('42nd St & 1st Avenue', '41st St & 2nd Avenue'),
#  '42nd St & 3rd Avenue': ('42nd St & 2nd Avenue', '43rd St & 3rd Avenue'),
#  '42nd St & Park Avenue': ('42nd St & 3rd Avenue', '43rd St & Park Avenue'),
#  '42nd St & 5th Avenue': ('42nd St & Park Avenue', '41st St & 5th Avenue'),
#  '42nd St & 6th Avenue': ('42nd St & 5th Avenue', '43rd St & 6th Avenue'),
#  '42nd St & 7th Avenue': ('42nd St & 6th Avenue', '41st St & 7th Avenue'),
#  '42nd St & 8th Avenue': ('42nd St & 7th Avenue', '43rd St & 8th Avenue'),
#  '42nd St & 9th Avenue': ('42nd St & 8th Avenue', '41st St & 9th Avenue'),
#  '42nd St & 10th Avenue': ('42nd St & 9th Avenue', '43rd St & 10th Avenue'),
#  '42nd St & 11th Avenue': ('42nd St & 10th Avenue', '41st St & 11th Avenue'),
#  '43rd St & 1st Avenue': ('43rd St & 2nd Avenue', '44th St & 1st Avenue'),
#  '43rd St & 2nd Avenue': ('43rd St & 3rd Avenue', '42nd St & 2nd Avenue'),
#  '43rd St & 3rd Avenue': ('43rd St & Park Avenue', '44th St & 3rd Avenue'),
#  '43rd St & Park Avenue': ('43rd St & 5th Avenue', '44th St & Park Avenue'),
#  '43rd St & 5th Avenue': ('43rd St & 6th Avenue', '42nd St & 5th Avenue'),
#  '43rd St & 6th Avenue': ('43rd St & 7th Avenue', '44th St & 6th Avenue'),
#  '43rd St & 7th Avenue': ('43rd St & 8th Avenue', '42nd St & 7th Avenue'),
#  '43rd St & 8th Avenue': ('43rd St & 9th Avenue', '44th St & 8th Avenue'),
#  '43rd St & 9th Avenue': ('43rd St & 10th Avenue', '42nd St & 9th Avenue'),
#  '43rd St & 10th Avenue': ('43rd St & 11th Avenue', '44th St & 10th Avenue'),
#  '43rd St & 11th Avenue': ('43rd St & 11th Avenue', '42nd St & 11th Avenue'),
#  '44th St & 1st Avenue': ('44th St & Avenue A', '45th St & 1st Avenue'),
#  '44th St & 2nd Avenue': ('44th St & 1st Avenue', '43rd St & 2nd Avenue'),
#  '44th St & 3rd Avenue': ('44th St & 2nd Avenue', '45th St & 3rd Avenue'),
#  '44th St & Park Avenue': ('44th St & 3rd Avenue', '45th St & Park Avenue'),
#  '44th St & 5th Avenue': ('44th St & Park Avenue', '43rd St & 5th Avenue'),
#  '44th St & 6th Avenue': ('44th St & 5th Avenue', '45th St & 6th Avenue'),
#  '44th St & 7th Avenue': ('44th St & 6th Avenue', '43rd St & 7th Avenue'),
#  '44th St & 8th Avenue': ('44th St & 7th Avenue', '45th St & 8th Avenue'),
#  '44th St & 9th Avenue': ('44th St & 8th Avenue', '43rd St & 9th Avenue'),
#  '44th St & 10th Avenue': ('44th St & 9th Avenue', '45th St & 10th Avenue'),
#  '44th St & 11th Avenue': ('44th St & 10th Avenue', '43rd St & 11th Avenue'),
#  '45th St & 1st Avenue': ('45th St & 2nd Avenue', '46th St & 1st Avenue'),
#  '45th St & 2nd Avenue': ('45th St & 3rd Avenue', '44th St & 2nd Avenue'),
#  '45th St & 3rd Avenue': ('45th St & Park Avenue', '46th St & 3rd Avenue'),
#  '45th St & Park Avenue': ('45th St & 5th Avenue', '46th St & Park Avenue'),
#  '45th St & 5th Avenue': ('45th St & 6th Avenue', '44th St & 5th Avenue'),
#  '45th St & 6th Avenue': ('45th St & 7th Avenue', '46th St & 6th Avenue'),
#  '45th St & 7th Avenue': ('45th St & 8th Avenue', '44th St & 7th Avenue'),
#  '45th St & 8th Avenue': ('45th St & 9th Avenue', '46th St & 8th Avenue'),
#  '45th St & 9th Avenue': ('45th St & 10th Avenue', '44th St & 9th Avenue'),
#  '45th St & 10th Avenue': ('45th St & 11th Avenue', '46th St & 10th Avenue'),
#  '45th St & 11th Avenue': ('45th St & 11th Avenue', '44th St & 11th Avenue'),
#  '46th St & 1st Avenue': ('46th St & Avenue A', '47th St & 1st Avenue'),
#  '46th St & 2nd Avenue': ('46th St & 1st Avenue', '45th St & 2nd Avenue'),
#  '46th St & 3rd Avenue': ('46th St & 2nd Avenue', '47th St & 3rd Avenue'),
#  '46th St & Park Avenue': ('46th St & 3rd Avenue', '47th St & Park Avenue'),
#  '46th St & 5th Avenue': ('46th St & Park Avenue', '45th St & 5th Avenue'),
#  '46th St & 6th Avenue': ('46th St & 5th Avenue', '47th St & 6th Avenue'),
#  '46th St & 7th Avenue': ('46th St & 6th Avenue', '45th St & 7th Avenue'),
#  '46th St & 8th Avenue': ('46th St & 7th Avenue', '47th St & 8th Avenue'),
#  '46th St & 9th Avenue': ('46th St & 8th Avenue', '45th St & 9th Avenue'),
#  '46th St & 10th Avenue': ('46th St & 9th Avenue', '47th St & 10th Avenue'),
#  '46th St & 11th Avenue': ('46th St & 10th Avenue', '45th St & 11th Avenue'),
#  '47th St & 1st Avenue': ('47th St & 2nd Avenue', '48th St & 1st Avenue'),
#  '47th St & 2nd Avenue': ('47th St & 3rd Avenue', '46th St & 2nd Avenue'),
#  '47th St & 3rd Avenue': ('47th St & Park Avenue', '48th St & 3rd Avenue'),
#  '47th St & Park Avenue': ('47th St & 5th Avenue', '48th St & Park Avenue'),
#  '47th St & 5th Avenue': ('47th St & 6th Avenue', '46th St & 5th Avenue'),
#  '47th St & 6th Avenue': ('47th St & 7th Avenue', '48th St & 6th Avenue'),
#  '47th St & 7th Avenue': ('47th St & 8th Avenue', '46th St & 7th Avenue'),
#  '47th St & 8th Avenue': ('47th St & 9th Avenue', '48th St & 8th Avenue'),
#  '47th St & 9th Avenue': ('47th St & 10th Avenue', '46th St & 9th Avenue'),
#  '47th St & 10th Avenue': ('47th St & 11th Avenue', '48th St & 10th Avenue'),
#  '47th St & 11th Avenue': ('47th St & 11th Avenue', '46th St & 11th Avenue'),
#  '48th St & 1st Avenue': ('48th St & Avenue A', '49th St & 1st Avenue'),
#  '48th St & 2nd Avenue': ('48th St & 1st Avenue', '47th St & 2nd Avenue'),
#  '48th St & 3rd Avenue': ('48th St & 2nd Avenue', '49th St & 3rd Avenue'),
#  '48th St & Park Avenue': ('48th St & 3rd Avenue', '49th St & Park Avenue'),
#  '48th St & 5th Avenue': ('48th St & Park Avenue', '47th St & 5th Avenue'),
#  '48th St & 6th Avenue': ('48th St & 5th Avenue', '49th St & 6th Avenue'),
#  '48th St & 7th Avenue': ('48th St & 6th Avenue', '47th St & 7th Avenue'),
#  '48th St & 8th Avenue': ('48th St & 7th Avenue', '49th St & 8th Avenue'),
#  '48th St & 9th Avenue': ('48th St & 8th Avenue', '47th St & 9th Avenue'),
#  '48th St & 10th Avenue': ('48th St & 9th Avenue', '49th St & 10th Avenue'),
#  '48th St & 11th Avenue': ('48th St & 10th Avenue', '47th St & 11th Avenue'),
#  '49th St & 1st Avenue': ('49th St & 2nd Avenue', '50th St & 1st Avenue'),
#  '49th St & 2nd Avenue': ('49th St & 3rd Avenue', '48th St & 2nd Avenue'),
#  '49th St & 3rd Avenue': ('49th St & Park Avenue', '50th St & 3rd Avenue'),
#  '49th St & Park Avenue': ('49th St & 5th Avenue', '50th St & Park Avenue'),
#  '49th St & 5th Avenue': ('49th St & 6th Avenue', '48th St & 5th Avenue'),
#  '49th St & 6th Avenue': ('49th St & 7th Avenue', '50th St & 6th Avenue'),
#  '49th St & 7th Avenue': ('49th St & 8th Avenue', '48th St & 7th Avenue'),
#  '49th St & 8th Avenue': ('49th St & 9th Avenue', '50th St & 8th Avenue'),
#  '49th St & 9th Avenue': ('49th St & 10th Avenue', '48th St & 9th Avenue'),
#  '49th St & 10th Avenue': ('49th St & 11th Avenue', '50th St & 10th Avenue'),
#  '49th St & 11th Avenue': ('49th St & 11th Avenue', '48th St & 11th Avenue'),
#  '50th St & 1st Avenue': ('50th St & Avenue A', '51st St & 1st Avenue'),
#  '50th St & 2nd Avenue': ('50th St & 1st Avenue', '49th St & 2nd Avenue'),
#  '50th St & 3rd Avenue': ('50th St & 2nd Avenue', '51st St & 3rd Avenue'),
#  '50th St & Park Avenue': ('50th St & 3rd Avenue', '51st St & Park Avenue'),
#  '50th St & 5th Avenue': ('50th St & Park Avenue', '49th St & 5th Avenue'),
#  '50th St & 6th Avenue': ('50th St & 5th Avenue', '51st St & 6th Avenue'),
#  '50th St & 7th Avenue': ('50th St & 6th Avenue', '49th St & 7th Avenue'),
#  '50th St & 8th Avenue': ('50th St & 7th Avenue', '51st St & 8th Avenue'),
#  '50th St & 9th Avenue': ('50th St & 8th Avenue', '49th St & 9th Avenue'),
#  '50th St & 10th Avenue': ('50th St & 9th Avenue', '51st St & 10th Avenue'),
#  '50th St & 11th Avenue': ('50th St & 10th Avenue', '49th St & 11th Avenue'),
#  '51st St & 1st Avenue': ('51st St & 2nd Avenue', '52nd St & 1st Avenue'),
#  '51st St & 2nd Avenue': ('51st St & 3rd Avenue', '50th St & 2nd Avenue'),
#  '51st St & 3rd Avenue': ('51st St & Park Avenue', '52nd St & 3rd Avenue'),
#  '51st St & Park Avenue': ('51st St & 5th Avenue', '52nd St & Park Avenue'),
#  '51st St & 5th Avenue': ('51st St & 6th Avenue', '50th St & 5th Avenue'),
#  '51st St & 6th Avenue': ('51st St & 7th Avenue', '52nd St & 6th Avenue'),
#  '51st St & 7th Avenue': ('51st St & 8th Avenue', '50th St & 7th Avenue'),
#  '51st St & 8th Avenue': ('51st St & 9th Avenue', '52nd St & 8th Avenue'),
#  '51st St & 9th Avenue': ('51st St & 10th Avenue', '50th St & 9th Avenue'),
#  '51st St & 10th Avenue': ('51st St & 11th Avenue', '52nd St & 10th Avenue'),
#  '51st St & 11th Avenue': ('51st St & 11th Avenue', '50th St & 11th Avenue'),
#  '52nd St & 1st Avenue': ('52nd St & Avenue A', '53rd St & 1st Avenue'),
#  '52nd St & 2nd Avenue': ('52nd St & 1st Avenue', '51st St & 2nd Avenue'),
#  '52nd St & 3rd Avenue': ('52nd St & 2nd Avenue', '53rd St & 3rd Avenue'),
#  '52nd St & Park Avenue': ('52nd St & 3rd Avenue', '53rd St & Park Avenue'),
#  '52nd St & 5th Avenue': ('52nd St & Park Avenue', '51st St & 5th Avenue'),
# ...
#   '69th St & Central Park West'),
#  '68th St & Columbus Avenue': ('68th St & Central Park West',
#   '67th St & Columbus Avenue'),
#  '68th St & Amsterdam Avenue': ('68th St & Columbus Avenue',
#   '69th St & Amsterdam Avenue'),
#  '68th St & West End Avenue': ('68th St & Amsterdam Avenue',
#   '67th St & West End Avenue'),
#  '69th St & 1st Avenue': ('69th St & 2nd Avenue', '70th St & 1st Avenue'),
#  '69th St & 2nd Avenue': ('69th St & 3rd Avenue', '68th St & 2nd Avenue'),
#  '69th St & 3rd Avenue': ('69th St & Park Avenue', '70th St & 3rd Avenue'),
#  '69th St & Park Avenue': ('69th St & 5th Avenue', '70th St & Park Avenue'),
#  '69th St & 5th Avenue': ('69th St & 6th Avenue', '68th St & 5th Avenue'),
#  '69th St & Central Park West': ('69th St & Columbus Avenue',
#   '70th St & Central Park West'),
#  '69th St & Columbus Avenue': ('69th St & Amsterdam Avenue',
#   '68th St & Columbus Avenue'),
#  '69th St & Amsterdam Avenue': ('69th St & West End Avenue',
#   '70th St & Amsterdam Avenue'),
#  '69th St & West End Avenue': ('69th St & West End Avenue',
#   '68th St & West End Avenue'),
#  '70th St & 1st Avenue': ('70th St & Avenue A', '71st St & 1st Avenue'),
#  '70th St & 2nd Avenue': ('70th St & 1st Avenue', '69th St & 2nd Avenue'),
#  '70th St & 3rd Avenue': ('70th St & 2nd Avenue', '71st St & 3rd Avenue'),
#  '70th St & Park Avenue': ('70th St & 3rd Avenue', '71st St & Park Avenue'),
#  '70th St & 5th Avenue': ('70th St & Park Avenue', '69th St & 5th Avenue'),
#  '70th St & Central Park West': ('70th St & 5th Avenue',
#   '71st St & Central Park West'),
#  '70th St & Columbus Avenue': ('70th St & Central Park West',
#   '69th St & Columbus Avenue'),
#  '70th St & Amsterdam Avenue': ('70th St & Columbus Avenue',
#   '71st St & Amsterdam Avenue'),
#  '70th St & West End Avenue': ('70th St & Amsterdam Avenue',
#   '69th St & West End Avenue'),
#  '71st St & 1st Avenue': ('71st St & 2nd Avenue', '72nd St & 1st Avenue'),
#  '71st St & 2nd Avenue': ('71st St & 3rd Avenue', '70th St & 2nd Avenue'),
#  '71st St & 3rd Avenue': ('71st St & Park Avenue', '72nd St & 3rd Avenue'),
#  '71st St & Park Avenue': ('71st St & 5th Avenue', '72nd St & Park Avenue'),
#  '71st St & 5th Avenue': ('71st St & 6th Avenue', '70th St & 5th Avenue'),
#  '71st St & Central Park West': ('71st St & Columbus Avenue',
#   '72nd St & Central Park West'),
#  '71st St & Columbus Avenue': ('71st St & Amsterdam Avenue',
#   '70th St & Columbus Avenue'),
#  '71st St & Amsterdam Avenue': ('71st St & West End Avenue',
#   '72nd St & Amsterdam Avenue'),
#  '71st St & West End Avenue': ('71st St & West End Avenue',
#   '70th St & West End Avenue'),
#  '72nd St & 1st Avenue': ('72nd St & Avenue A', '73rd St & 1st Avenue'),
#  '72nd St & 2nd Avenue': ('72nd St & 1st Avenue', '71st St & 2nd Avenue'),
#  '72nd St & 3rd Avenue': ('72nd St & 2nd Avenue', '73rd St & 3rd Avenue'),
#  '72nd St & Park Avenue': ('72nd St & 3rd Avenue', '73rd St & Park Avenue'),
#  '72nd St & 5th Avenue': ('72nd St & Park Avenue', '71st St & 5th Avenue'),
#  '72nd St & Central Park West': ('72nd St & 5th Avenue',
#   '73rd St & Central Park West'),
#  '72nd St & Columbus Avenue': ('72nd St & Central Park West',
#   '71st St & Columbus Avenue'),
#  '72nd St & Amsterdam Avenue': ('72nd St & Columbus Avenue',
#   '73rd St & Amsterdam Avenue'),
#  '72nd St & West End Avenue': ('72nd St & Amsterdam Avenue',
#   '71st St & West End Avenue'),
#  '73rd St & 1st Avenue': ('73rd St & 2nd Avenue', '74th St & 1st Avenue'),
#  '73rd St & 2nd Avenue': ('73rd St & 3rd Avenue', '72nd St & 2nd Avenue'),
#  '73rd St & 3rd Avenue': ('73rd St & Park Avenue', '74th St & 3rd Avenue'),
#  '73rd St & Park Avenue': ('73rd St & 5th Avenue', '74th St & Park Avenue'),
#  '73rd St & 5th Avenue': ('73rd St & 6th Avenue', '72nd St & 5th Avenue'),
#  '73rd St & Central Park West': ('73rd St & Columbus Avenue',
#   '74th St & Central Park West'),
#  '73rd St & Columbus Avenue': ('73rd St & Amsterdam Avenue',
#   '72nd St & Columbus Avenue'),
#  '73rd St & Amsterdam Avenue': ('73rd St & West End Avenue',
#   '74th St & Amsterdam Avenue'),
#  '73rd St & West End Avenue': ('73rd St & West End Avenue',
#   '72nd St & West End Avenue'),
#  '74th St & 1st Avenue': ('74th St & Avenue A', '75th St & 1st Avenue'),
#  '74th St & 2nd Avenue': ('74th St & 1st Avenue', '73rd St & 2nd Avenue'),
#  '74th St & 3rd Avenue': ('74th St & 2nd Avenue', '75th St & 3rd Avenue'),
#  '74th St & Park Avenue': ('74th St & 3rd Avenue', '75th St & Park Avenue'),
#  '74th St & 5th Avenue': ('74th St & Park Avenue', '73rd St & 5th Avenue'),
#  '74th St & Central Park West': ('74th St & 5th Avenue',
#   '75th St & Central Park West'),
#  '74th St & Columbus Avenue': ('74th St & Central Park West',
#   '73rd St & Columbus Avenue'),
#  '74th St & Amsterdam Avenue': ('74th St & Columbus Avenue',
#   '75th St & Amsterdam Avenue'),
#  '74th St & West End Avenue': ('74th St & Amsterdam Avenue',
#   '73rd St & West End Avenue'),
#  '75th St & 1st Avenue': ('75th St & 2nd Avenue', '76th St & 1st Avenue'),
#  '75th St & 2nd Avenue': ('75th St & 3rd Avenue', '74th St & 2nd Avenue'),
#  '75th St & 3rd Avenue': ('75th St & Park Avenue', '76th St & 3rd Avenue'),
#  '75th St & Park Avenue': ('75th St & 5th Avenue', '76th St & Park Avenue'),
#  '75th St & 5th Avenue': ('75th St & 6th Avenue', '74th St & 5th Avenue'),
#  '75th St & Central Park West': ('75th St & Columbus Avenue',
#   '76th St & Central Park West'),
#  '75th St & Columbus Avenue': ('75th St & Amsterdam Avenue',
#   '74th St & Columbus Avenue'),
#  '75th St & Amsterdam Avenue': ('75th St & West End Avenue',
#   '76th St & Amsterdam Avenue'),
#  '75th St & West End Avenue': ('75th St & West End Avenue',
#   '74th St & West End Avenue'),
#  '76th St & 1st Avenue': ('76th St & Avenue A', '77th St & 1st Avenue'),
#  '76th St & 2nd Avenue': ('76th St & 1st Avenue', '75th St & 2nd Avenue'),
#  '76th St & 3rd Avenue': ('76th St & 2nd Avenue', '77th St & 3rd Avenue'),
#  '76th St & Park Avenue': ('76th St & 3rd Avenue', '77th St & Park Avenue'),
#  '76th St & 5th Avenue': ('76th St & Park Avenue', '75th St & 5th Avenue'),
#  '76th St & Central Park West': ('76th St & 5th Avenue',
#   '77th St & Central Park West'),
#  '76th St & Columbus Avenue': ('76th St & Central Park West',
#   '75th St & Columbus Avenue'),
#  '76th St & Amsterdam Avenue': ('76th St & Columbus Avenue',
#   '77th St & Amsterdam Avenue'),
#  '76th St & West End Avenue': ('76th St & Amsterdam Avenue',
#   '75th St & West End Avenue'),
#  '77th St & 1st Avenue': ('77th St & 2nd Avenue', '78th St & 1st Avenue'),
#  '77th St & 2nd Avenue': ('77th St & 3rd Avenue', '76th St & 2nd Avenue'),
#  '77th St & 3rd Avenue': ('77th St & Park Avenue', '78th St & 3rd Avenue'),
#  '77th St & Park Avenue': ('77th St & 5th Avenue', '78th St & Park Avenue'),
#  '77th St & 5th Avenue': ('77th St & 6th Avenue', '76th St & 5th Avenue'),
#  '77th St & Central Park West': ('77th St & Columbus Avenue',
#   '78th St & Central Park West'),
#  '77th St & Columbus Avenue': ('77th St & Amsterdam Avenue',
#   '76th St & Columbus Avenue'),
#  '77th St & Amsterdam Avenue': ('77th St & West End Avenue',
#   '78th St & Amsterdam Avenue'),
#  '77th St & West End Avenue': ('77th St & West End Avenue',
#   '76th St & West End Avenue'),
#  '78th St & 1st Avenue': ('78th St & Avenue A', '79th St & 1st Avenue'),
#  '78th St & 2nd Avenue': ('78th St & 1st Avenue', '77th St & 2nd Avenue'),
#  '78th St & 3rd Avenue': ('78th St & 2nd Avenue', '79th St & 3rd Avenue'),
#  '78th St & Park Avenue': ('78th St & 3rd Avenue', '79th St & Park Avenue'),
#  '78th St & 5th Avenue': ('78th St & Park Avenue', '77th St & 5th Avenue'),
#  '78th St & Central Park West': ('78th St & 5th Avenue',
#   '79th St & Central Park West'),
#  '78th St & Columbus Avenue': ('78th St & Central Park West',
#   '77th St & Columbus Avenue'),
#  '78th St & Amsterdam Avenue': ('78th St & Columbus Avenue',
#   '79th St & Amsterdam Avenue'),
#  '78th St & West End Avenue': ('78th St & Amsterdam Avenue',
#   '77th St & West End Avenue'),
#  '79th St & 1st Avenue': ('79th St & 2nd Avenue', '80th St & 1st Avenue'),
#  '79th St & 2nd Avenue': ('79th St & 3rd Avenue', '78th St & 2nd Avenue'),
#  '79th St & 3rd Avenue': ('79th St & Park Avenue', '80th St & 3rd Avenue'),
#  '79th St & Park Avenue': ('79th St & 5th Avenue', '80th St & Park Avenue'),
#  '79th St & 5th Avenue': ('79th St & 6th Avenue', '78th St & 5th Avenue'),
#  '79th St & Central Park West': ('79th St & Columbus Avenue',
#   '80th St & Central Park West'),
#  '79th St & Columbus Avenue': ('79th St & Amsterdam Avenue',
#   '78th St & Columbus Avenue'),
#  '79th St & Amsterdam Avenue': ('79th St & West End Avenue',
#   '80th St & Amsterdam Avenue'),
#  '79th St & West End Avenue': ('79th St & West End Avenue',
#   '78th St & West End Avenue'),
#  '80th St & 1st Avenue': ('80th St & Avenue A', '81st St & 1st Avenue'),
#  '80th St & 2nd Avenue': ('80th St & 1st Avenue', '79th St & 2nd Avenue'),
#  '80th St & 3rd Avenue': ('80th St & 2nd Avenue', '81st St & 3rd Avenue'),
#  '80th St & Park Avenue': ('80th St & 3rd Avenue', '81st St & Park Avenue'),
#  '80th St & 5th Avenue': ('80th St & Park Avenue', '79th St & 5th Avenue'),
#  '80th St & Central Park West': ('80th St & 5th Avenue',
#   '81st St & Central Park West'),
#  '80th St & Columbus Avenue': ('80th St & Central Park West',
#   '79th St & Columbus Avenue'),
#  '80th St & Amsterdam Avenue': ('80th St & Columbus Avenue',
#   '81st St & Amsterdam Avenue'),
#  '80th St & West End Avenue': ('80th St & Amsterdam Avenue',
#   '79th St & West End Avenue'),
#  '81st St & 1st Avenue': ('81st St & 2nd Avenue', '82nd St & 1st Avenue'),
#  '81st St & 2nd Avenue': ('81st St & 3rd Avenue', '80th St & 2nd Avenue'),
#  '81st St & 3rd Avenue': ('81st St & Park Avenue', '82nd St & 3rd Avenue'),
#  '81st St & Park Avenue': ('81st St & 5th Avenue', '82nd St & Park Avenue'),
#  '81st St & 5th Avenue': ('81st St & 6th Avenue', '80th St & 5th Avenue'),
#  '81st St & Central Park West': ('81st St & Columbus Avenue',
#   '82nd St & Central Park West'),
#  '81st St & Columbus Avenue': ('81st St & Amsterdam Avenue',
#   '80th St & Columbus Avenue'),
#  '81st St & Amsterdam Avenue': ('81st St & West End Avenue',
#   '82nd St & Amsterdam Avenue'),
#  '81st St & West End Avenue': ('81st St & West End Avenue',
#   '80th St & West End Avenue'),
#  '82nd St & 1st Avenue': ('82nd St & Avenue A', '83rd St & 1st Avenue'),
#  '82nd St & 2nd Avenue': ('82nd St & 1st Avenue', '81st St & 2nd Avenue'),
#  '82nd St & 3rd Avenue': ('82nd St & 2nd Avenue', '83rd St & 3rd Avenue'),
#  '82nd St & Park Avenue': ('82nd St & 3rd Avenue', '83rd St & Park Avenue'),
#  '82nd St & 5th Avenue': ('82nd St & Park Avenue', '81st St & 5th Avenue'),
#  '82nd St & Central Park West': ('82nd St & 5th Avenue',
#   '83rd St & Central Park West'),
#  '82nd St & Columbus Avenue': ('82nd St & Central Park West',
#   '81st St & Columbus Avenue'),
#  '82nd St & Amsterdam Avenue': ('82nd St & Columbus Avenue',
#   '83rd St & Amsterdam Avenue'),
#  '82nd St & West End Avenue': ('82nd St & Amsterdam Avenue',
#   '81st St & West End Avenue'),
#  '83rd St & 1st Avenue': ('83rd St & 2nd Avenue', '84th St & 1st Avenue'),
#  '83rd St & 2nd Avenue': ('83rd St & 3rd Avenue', '82nd St & 2nd Avenue'),
#  '83rd St & 3rd Avenue': ('83rd St & Park Avenue', '84th St & 3rd Avenue'),
#  '83rd St & Park Avenue': ('83rd St & 5th Avenue', '84th St & Park Avenue'),
#  '83rd St & 5th Avenue': ('83rd St & 6th Avenue', '82nd St & 5th Avenue'),
#  '83rd St & Central Park West': ('83rd St & Columbus Avenue',
#   '84th St & Central Park West'),
#  '83rd St & Columbus Avenue': ('83rd St & Amsterdam Avenue',
#   '82nd St & Columbus Avenue'),
#  '83rd St & Amsterdam Avenue': ('83rd St & West End Avenue',
#   '84th St & Amsterdam Avenue'),
#  '83rd St & West End Avenue': ('83rd St & West End Avenue',
#   '82nd St & West End Avenue'),
#  '84th St & 1st Avenue': ('84th St & Avenue A', '85th St & 1st Avenue'),
#  '84th St & 2nd Avenue': ('84th St & 1st Avenue', '83rd St & 2nd Avenue'),
#  '84th St & 3rd Avenue': ('84th St & 2nd Avenue', '85th St & 3rd Avenue'),
#  '84th St & Park Avenue': ('84th St & 3rd Avenue', '85th St & Park Avenue'),
#  '84th St & 5th Avenue': ('84th St & Park Avenue', '83rd St & 5th Avenue'),
#  '84th St & Central Park West': ('84th St & 5th Avenue',
#   '85th St & Central Park West'),
#  '84th St & Columbus Avenue': ('84th St & Central Park West',
#   '83rd St & Columbus Avenue'),
#  '84th St & Amsterdam Avenue': ('84th St & Columbus Avenue',
#   '85th St & Amsterdam Avenue'),
#  '84th St & West End Avenue': ('84th St & Amsterdam Avenue',
#   '83rd St & West End Avenue'),
#  '85th St & 1st Avenue': ('85th St & 2nd Avenue', '86th St & 1st Avenue'),
#  '85th St & 2nd Avenue': ('85th St & 3rd Avenue', '84th St & 2nd Avenue'),
#  '85th St & 3rd Avenue': ('85th St & Park Avenue', '86th St & 3rd Avenue'),
#  '85th St & Park Avenue': ('85th St & 5th Avenue', '86th St & Park Avenue'),
#  '85th St & 5th Avenue': ('85th St & 6th Avenue', '84th St & 5th Avenue'),
#  '85th St & Central Park West': ('85th St & Columbus Avenue',
#   '86th St & Central Park West'),
#  '85th St & Columbus Avenue': ('85th St & Amsterdam Avenue',
#   '84th St & Columbus Avenue'),
#  '85th St & Amsterdam Avenue': ('85th St & West End Avenue',
#   '86th St & Amsterdam Avenue'),
#  '85th St & West End Avenue': ('85th St & West End Avenue',
#   '84th St & West End Avenue'),
#  '86th St & 1st Avenue': ('86th St & Avenue A', '87th St & 1st Avenue'),
#  '86th St & 2nd Avenue': ('86th St & 1st Avenue', '85th St & 2nd Avenue'),
#  '86th St & 3rd Avenue': ('86th St & 2nd Avenue', '87th St & 3rd Avenue'),
#  '86th St & Park Avenue': ('86th St & 3rd Avenue', '87th St & Park Avenue'),
#  '86th St & 5th Avenue': ('86th St & Park Avenue', '85th St & 5th Avenue'),
#  '86th St & Central Park West': ('86th St & 5th Avenue',
#   '87th St & Central Park West'),
#  '86th St & Columbus Avenue': ('86th St & Central Park West',
#   '85th St & Columbus Avenue'),
#  '86th St & Amsterdam Avenue': ('86th St & Columbus Avenue',
#   '87th St & Amsterdam Avenue'),
#  '86th St & West End Avenue': ('86th St & Amsterdam Avenue',
#   '85th St & West End Avenue'),
#  '87th St & 1st Avenue': ('87th St & 2nd Avenue', '88th St & 1st Avenue'),
#  '87th St & 2nd Avenue': ('87th St & 3rd Avenue', '86th St & 2nd Avenue'),
#  '87th St & 3rd Avenue': ('87th St & Park Avenue', '88th St & 3rd Avenue'),
#  '87th St & Park Avenue': ('87th St & 5th Avenue', '88th St & Park Avenue'),
#  '87th St & 5th Avenue': ('87th St & 6th Avenue', '86th St & 5th Avenue'),
#  '87th St & Central Park West': ('87th St & Columbus Avenue',
#   '88th St & Central Park West'),
#  '87th St & Columbus Avenue': ('87th St & Amsterdam Avenue',
#   '86th St & Columbus Avenue'),
#  '87th St & Amsterdam Avenue': ('87th St & West End Avenue',
#   '88th St & Amsterdam Avenue'),
#  '87th St & West End Avenue': ('87th St & West End Avenue',
#   '86th St & West End Avenue'),
#  '88th St & 1st Avenue': ('88th St & Avenue A', '89th St & 1st Avenue'),
#  '88th St & 2nd Avenue': ('88th St & 1st Avenue', '87th St & 2nd Avenue'),
#  '88th St & 3rd Avenue': ('88th St & 2nd Avenue', '89th St & 3rd Avenue'),
#  '88th St & Park Avenue': ('88th St & 3rd Avenue', '89th St & Park Avenue'),
#  '88th St & 5th Avenue': ('88th St & Park Avenue', '87th St & 5th Avenue'),
#  '88th St & Central Park West': ('88th St & 5th Avenue',
#   '89th St & Central Park West'),
#  '88th St & Columbus Avenue': ('88th St & Central Park West',
#   '87th St & Columbus Avenue'),
#  '88th St & Amsterdam Avenue': ('88th St & Columbus Avenue',
#   '89th St & Amsterdam Avenue'),
#  '88th St & West End Avenue': ('88th St & Amsterdam Avenue',
#   '87th St & West End Avenue'),
#  '89th St & 1st Avenue': ('89th St & 2nd Avenue', '90th St & 1st Avenue'),
#  '89th St & 2nd Avenue': ('89th St & 3rd Avenue', '88th St & 2nd Avenue'),
#  '89th St & 3rd Avenue': ('89th St & Park Avenue', '90th St & 3rd Avenue'),
#  '89th St & Park Avenue': ('89th St & 5th Avenue', '90th St & Park Avenue'),
#  '89th St & 5th Avenue': ('89th St & 6th Avenue', '88th St & 5th Avenue'),
#  '89th St & Central Park West': ('89th St & Columbus Avenue',
#   '90th St & Central Park West'),
#  '89th St & Columbus Avenue': ('89th St & Amsterdam Avenue',
#   '88th St & Columbus Avenue'),
#  '89th St & Amsterdam Avenue': ('89th St & West End Avenue',
#   '90th St & Amsterdam Avenue'),
#  ...}

# %%
i = 0
while i < 5:
    testing = (junctions[random.randint(0, len(junctions) - 1)])
    print ("Adj intersections of " + num2str(testing) + " are " + adj_graph[num2str(testing)][0] + " and " + adj_graph[num2str(testing)][1])
    i += 1
# Out:
# Adj intersections of 19th St & 6th Avenue are 19th St & 7th Avenue and 20th St & 6th Avenue
# Adj intersections of 69th St & 1st Avenue are 69th St & 2nd Avenue and 70th St & 1st Avenue
# Adj intersections of 50th St & 5th Avenue are 50th St & Park Avenue and 49th St & 5th Avenue
# Adj intersections of 12th St & Avenue A are 12th St & Avenue B and 11th St & Avenue A
# Adj intersections of 35th St & 11th Avenue are 35th St & 11th Avenue and 34th St & 11th Avenue

# %% [markdown]
# #### Testing the locality of each intersection

# %%
i = 0
while i < 10:
    testing = (junctions[random.randint(0, len(junctions) - 1)])
    print (locality(testing))
    i += 1
# Out:
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan

# %% [markdown]
# #### Gmaps.geocode has some bugs
# a = (5, 'Avenue D') <br>
# gmaps.geocode('Intersection of ' + num2str(a)  + 'Manhattan NY') return -> [], but the intersection exists

# %% [markdown]
# #### Creating the output json file

# %%
output_path = 'Manhattan_adj_graph.json'
with open (output_path,'w+') as f:
    json.dump(adj_graph, f, sort_keys = False)

# %% [markdown]
# #### Creating dictionary of all gps coordinates of all input intersections

# %%
# gps_dict = {}

# for i in tqdm(range(0,len(junctions))):
#     testing = (junctions[i])
#     gps_dict[num2str(testing)] =  gps_coords(testing)

# %%
#gps_dict

# %% [markdown]
# #### Putting all gps data in a json file coz it takes 20 mins to create one

# %%
# output_path = 'gps_dict.json'
# with open (output_path,'w+') as f:
#     json.dump(gps_dict, f, sort_keys = False)

# %% [markdown]
# #### Loading the gps data

# %%
with open('gps_dict.json') as json_data:
    gps_data = json.load(json_data)

# %%
print(gps_data)
# Out:
# {'1st St & Avenue D': ['Not found', 'Not found'], '1st St & Avenue C': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & Avenue B': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & Avenue A': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 1st Avenue': [40.7232818, -73.9884111], '1st St & 2nd Avenue': [40.7242997, -73.9908286], '1st St & 3rd Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & Park Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 5th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 6th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 7th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 8th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '1st St & 9th Avenue': [40.7281724, -73.9848693], '1st St & 10th Avenue': [40.7287833, -73.9844341], '1st St & 11th Avenue': [40.7293824, -73.9840037], '2nd St & Avenue D': ['Not found', 'Not found'], '2nd St & Avenue C': [40.7230145, -73.9857665], '2nd St & Avenue B': [40.7220306, -73.9834557], '2nd St & Avenue A': [40.7230145, -73.9857665], '2nd St & 1st Avenue': [40.7239323, -73.98795779999999], '2nd St & 2nd Avenue': [40.7249271, -73.9903621], '2nd St & 3rd Avenue': [40.7255879, -73.989893], '2nd St & Park Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '2nd St & 5th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '2nd St & 6th Avenue': [40.7274134, -73.9885281], '2nd St & 7th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '2nd St & 8th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '2nd St & 9th Avenue': [40.7291746, -73.9872494], '2nd St & 10th Avenue': [40.7297745, -73.9868067], '2nd St & 11th Avenue': [40.730379, -73.9863665], '3rd St & Avenue D': ['Not found', 'Not found'], '3rd St & Avenue C': [40.7236548, -73.9852944], '3rd St & Avenue B': [40.7226831, -73.9829783], '3rd St & Avenue A': [40.7236548, -73.9852944], '3rd St & 1st Avenue': [40.7245817, -73.9874952], '3rd St & 2nd Avenue': [40.7255879, -73.989893], '3rd St & 3rd Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '3rd St & Park Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '3rd St & 5th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '3rd St & 6th Avenue': [40.7310719, -74.0014265], '3rd St & 7th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '3rd St & 8th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '3rd St & 9th Avenue': [40.7301174, -73.9894735], '3rd St & 10th Avenue': [40.73071729999999, -73.98906099999999], '3rd St & 11th Avenue': [40.7313232, -73.98861769999999], '4th St & Avenue D': ['Not found', 'Not found'], '4th St & Avenue C': [40.7242667, -73.9848465], '4th St & Avenue B': [40.7232838, -73.9825451], '4th St & Avenue A': [40.7242667, -73.9848465], '4th St & 1st Avenue': [40.7251936, -73.98704719999999], '4th St & 2nd Avenue': [40.7261987, -73.9894438], '4th St & 3rd Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '4th St & Park Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '4th St & 5th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '4th St & 6th Avenue': [40.7317091, -74.0009719], '4th St & 7th Avenue': [40.73371789999999, -74.0027623], '4th St & 8th Avenue': [40.7382921, -74.00397459999999], '4th St & 9th Avenue': [40.730567, -73.9904889], '4th St & 10th Avenue': [40.7342534, -74.0029836], '4th St & 11th Avenue': [40.736204, -74.0035456], '5th St & Avenue D': ['Not found', 'Not found'], '5th St & Avenue C': [40.7248612, -73.98442], '5th St & Avenue B': [40.7238917, -73.9820956], '5th St & Avenue A': [40.7248612, -73.98442], '5th St & 1st Avenue': [40.7257927, -73.9866112], '5th St & 2nd Avenue': [40.72679979999999, -73.98898129999999], '5th St & 3rd Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '5th St & Park Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '5th St & 5th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '5th St & 6th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], '5th St & 7th Avenue': ['Not in Manhattan ', 'Not in Manhattan'], ' ...

# %% [markdown]
# ## Final Output

# %%
address = (junctions[random.randint(0, len(junctions) - 1)])
print (num2str(address)) ## any random address
print (gps_data[num2str(address)]) ## Its gps 
print (intersections(address[0], address[1])) ## Its adjacent intersections
print (gps_data[intersections(address[0], address[1])[0]], gps_data[intersections(address[0], address[1])[1]]) ## their gps
# Out:
# 87th St & 2nd Avenue
# [40.7785824, -73.95132029999999]
# ('87th St & 3rd Avenue', '86th St & 2nd Avenue')
# [40.779489, -73.9534669] [40.7778909, -73.9517869]
